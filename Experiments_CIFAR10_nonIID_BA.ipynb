# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "CIFAR10"
MODEL_NAME = "ResNet18"
DD_TYPE = 'MILD_NON_IID'
ALPHA = 1
NUM_PEERS = 20 # "number of peers: K" 
FRAC_PEERS = 1 #'the fraction of peers: C to bel selected in each round'
SEED = 0 #fixed seed
random.seed(SEED)
CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 100 #"number of rounds of federated model training"
LOCAL_EPOCHS = 3 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 1000
LOCAL_BS = 32 #"local batch size: B for each peer"
LOCAL_LR =  0.01#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Plane':0,
               'Car':1, 
               'Bird':2, 
               'Cat':3, 
               'Deer':4,
               'Dog':5, 
               'Frog':6, 
               'Horse':7, 
               'Ship':8, 
               'Truck':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"
DEVICE = torch.device(DEVICE)

SOURCE_CLASS = 1 # the source class, Car
TARGET_CLASS = 0 # the target class, Plane

CLASS_PER_PEER = 1
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1

# %%
# Baseline|: FedAvg-no attacks (FL)
RULE = 'fedavg'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
# --> Loading of CIFAR10 dataset
# Files already downloaded and verified
# Files already downloaded and verified
# --> Dataset has been loaded!
# --> Creating ResNet18 model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: CIFAR10
# Data distribution: MILD_NON_IID
# Aggregation rule: fedavg
# Attack Type: backdoor
# Attackers Ratio: 10.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
# Average of peers' local losses: 1.759516
#
# Average test loss: 2.3394, Test accuracy: 1004/10000 (10.04%)
#
# Class      - Accuracy
# Plane      - 0.0
# Car        - 0.0
# Bird       - 99.0
# Cat        - 0.0
# Deer       - 0.0
# Dog        - 0.0
# Frog       - 0.0
# Horse      - 1.4
# Ship       - 0.0
# Truck      - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |

# %%
RULE = 'median'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)

# %%
RULE = 'tmean'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)

# %%
RULE = 'mkrum'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
# --> Loading of CIFAR10 dataset
# Files already downloaded and verified
# Files already downloaded and verified
# --> Dataset has been loaded!
# --> Creating ResNet18 model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: CIFAR10
# Data distribution: MILD_NON_IID
# Aggregation rule: mkrum
# Attack Type: backdoor
# Attackers Ratio: 10.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
# Average of peers' local losses: 1.760877
#
# Average test loss: 2.3518, Test accuracy: 1000/10000 (10.00%)
#
# Class      - Accuracy
# Plane      - 0.0
# Car        - 0.0
# Bird       - 100.0
# Cat        - 0.0
# Deer       - 0.0
# Dog        - 0.0
# Frog       - 0.0
# Horse      - 0.0
# Ship       - 0.0
# Truck      - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
# Average of peers' local losses: 1.591148
#
# Average test loss: 2.2886, Test accuracy: 1019/10000 (10.19%)
#
# Class      - Accuracy
# Plane      - 1.9
# Car        - 0.0
# Bird       - 99.9
# Cat        - 0.0
# Deer       - 0.0
# Dog        - 0.1
# Frog       - 0.0
# Horse      - 0.0
# Ship       - 0.0
# Truck      - 0.0
#
# Backdoor ASR 2.3
#
#  | Global training round : 3/100 |
#
# Average of peers' local losses: 1.416207
#
# Average test loss: 1.8975, Test accuracy: 2942/10000 (29.42%)
#
# Class      - Accuracy
# Plane      - 57.3
# Car        - 7.3
# Bird       - 83.1
# Cat        - 25.5
# Deer       - 0.0
# Dog        - 26.8
# Frog       - 28.6
# Horse      - 16.6
# Ship       - 3.8
# Truck      - 45.2
#
# Backdoor ASR 19.8
#
#  | Global training round : 4/100 |
#
# Average of peers' local losses: 1.235858
#
# Average test loss: 1.4518, Test accuracy: 4818/10000 (48.18%)
#
# Class      - Accuracy
# Plane      - 60.1
# Car        - 40.0
# Bird       - 50.1
# Cat        - 21.1
# Deer       - 45.0
# Dog        - 55.9
# Frog       - 55.2
# Horse      - 43.0
# Ship       - 41.6
# Truck      - 69.8
#
# Backdoor ASR 7.1
#
#  | Global training round : 5/100 |
#
# Average of peers' local losses: 1.077532
#
# Average test loss: 1.2646, Test accuracy: 5446/10000 (54.46%)
#
# Class      - Accuracy
# Plane      - 63.1
# Car        - 48.1
# Bird       - 38.1
# Cat        - 29.4
# Deer       - 46.2
# Dog        - 55.1
# Frog       - 77.5
# Horse      - 53.7
# Ship       - 59.7
# Truck      - 73.7
#
# Backdoor ASR 2.8
#
#  | Global training round : 6/100 |
#
# Average of peers' local losses: 0.935281
#
# Average test loss: 1.1696, Test accuracy: 5835/10000 (58.35%)
#
# Class      - Accuracy
# Plane      - 64.5
# Car        - 66.2
# Bird       - 35.2
# Cat        - 21.0
# Deer       - 59.4
# Dog        - 61.2
# Frog       - 80.4
# Horse      - 61.8
# Ship       - 66.2
# Truck      - 67.6
#
# Backdoor ASR 2.8
#
#  | Global training round : 7/100 |
#
# Average of peers' local losses: 0.825307
#
# Average test loss: 1.0941, Test accuracy: 6140/10000 (61.40%)
#
# Class      - Accuracy
# Plane      - 68.6
# Car        - 57.9
# Bird       - 43.5
# Cat        - 39.5
# Deer       - 59.4
# Dog        - 59.2
# Frog       - 77.1
# Horse      - 61.6
# Ship       - 72.9
# Truck      - 74.3
#
# Backdoor ASR 4.2
#
#  | Global training round : 8/100 |
#
# Average of peers' local losses: 0.728855
#
# Average test loss: 1.0740, Test accuracy: 6345/10000 (63.45%)
#
# Class      - Accuracy
# Plane      - 66.8
# Car        - 65.8
# Bird       - 42.4
# Cat        - 28.5
# Deer       - 63.2
# Dog        - 61.5
# Frog       - 82.8
# Horse      - 67.9
# Ship       - 79.2
# Truck      - 76.4
#
# Backdoor ASR 2.1
#
#  | Global training round : 9/100 |
#
# Average of peers' local losses: 0.656002
#
# Average test loss: 1.0610, Test accuracy: 6464/10000 (64.64%)
#
# Class      - Accuracy
# Plane      - 71.5
# Car        - 68.4
# Bird       - 46.1
# Cat        - 27.8
# Deer       - 65.5
# Dog        - 60.9
# Frog       - 86.1
# Horse      - 66.3
# Ship       - 80.4
# Truck      - 73.4
#
# Backdoor ASR 3.3
#
#  | Global training round : 10/100 |
#
# Average of peers' local losses: 0.591518
#
# Average test loss: 1.0341, Test accuracy: 6597/10000 (65.97%)
#
# Class      - Accuracy
# Plane      - 71.5
# Car        - 69.9
# Bird       - 48.6
# Cat        - 27.2
# Deer       - 63.9
# Dog        - 65.2
# Frog       - 85.4
# Horse      - 68.8
# Ship       - 81.5
# Truck      - 77.7
#
# Backdoor ASR 3.1
#
#  | Global training round : 11/100 |
#
# Average of peers' local losses: 0.554622
#
# Average test loss: 1.0271, Test accuracy: 6718/10000 (67.18%)
#
# Class      - Accuracy
# Plane      - 72.3
# Car        - 72.3
# Bird       - 44.5
# Cat        - 32.1
# Deer       - 71.9
# Dog        - 62.4
# Frog       - 85.7
# Horse      - 72.0
# Ship       - 83.7
# Truck      - 74.9
#
# Backdoor ASR 3.0
#
#  | Global training round : 12/100 |
#
# Average of peers' local losses: 0.512896
#
# Average test loss: 1.0422, Test accuracy: 6755/10000 (67.55%)
#
# Class      - Accuracy
# Plane      - 73.3
# Car        - 70.6
# Bird       - 44.9
# Cat        - 33.5
# Deer       - 67.2
# Dog        - 62.0
# Frog       - 89.4
# Horse      - 72.0
# Ship       - 85.4
# Truck      - 77.2
#
# Backdoor ASR 2.8
#
#  | Global training round : 13/100 |
#
# Average of peers' local losses: 0.482317
#
# Average test loss: 1.0176, Test accuracy: 6808/10000 (68.08%)
#
# Class      - Accuracy
# Plane      - 70.0
# Car        - 75.4
# Bird       - 48.9
# Cat        - 32.4
# Deer       - 65.7
# Dog        - 66.1
# Frog       - 86.6
# Horse      - 73.1
# Ship       - 83.4
# Truck      - 79.2
#
# Backdoor ASR 3.2
#
#  | Global training round : 14/100 |
#
# Average of peers' local losses: 0.443365
#
# Average test loss: 1.0349, Test accuracy: 6828/10000 (68.28%)
#
# Class      - Accuracy
# Plane      - 72.0
# Car        - 72.3
# Bird       - 45.8
# Cat        - 34.5
# Deer       - 67.6
# Dog        - 64.8
# Frog       - 87.7
# Horse      - 73.3
# Ship       - 84.4
# Truck      - 80.4
#
# Backdoor ASR 2.7
#
#  | Global training round : 15/100 |
#
# Average of peers' local losses: 0.420880
#
# Average test loss: 1.0087, Test accuracy: 6926/10000 (69.26%)
#
# Class      - Accuracy
# Plane      - 74.8
# Car        - 78.6
# Bird       - 51.3
# Cat        - 28.5
# Deer       - 67.0
# Dog        - 68.7
# Frog       - 88.0
# Horse      - 74.5
# Ship       - 83.7
# Truck      - 77.5
#
# Backdoor ASR 4.1
#
#  | Global training round : 16/100 |
#
# Average of peers' local losses: 0.404406
#
# Average test loss: 1.0047, Test accuracy: 6937/10000 (69.37%)
#
# Class      - Accuracy
# Plane      - 76.6
# Car        - 76.4
# Bird       - 48.7
# Cat        - 31.3
# Deer       - 71.2
# Dog        - 65.3
# Frog       - 86.9
# Horse      - 72.8
# Ship       - 84.8
# Truck      - 79.7
#
# Backdoor ASR 4.2
#
#  | Global training round : 17/100 |
#
# Average of peers' local losses: 0.378019
#
# Average test loss: 0.9772, Test accuracy: 7023/10000 (70.23%)
#
# Class      - Accuracy
# Plane      - 79.0
# Car        - 78.3
# Bird       - 52.2
# Cat        - 37.7
# Deer       - 69.1
# Dog        - 66.9
# Frog       - 84.7
# Horse      - 73.6
# Ship       - 81.8
# Truck      - 79.0
#
# Backdoor ASR 6.1
#
#  | Global training round : 18/100 |
#
# Average of peers' local losses: 0.361301
#
# Average test loss: 1.0170, Test accuracy: 6963/10000 (69.63%)
#
# Class      - Accuracy
# Plane      - 75.9
# Car        - 75.5
# Bird       - 45.9
# Cat        - 32.3
# Deer       - 67.7
# Dog        - 69.2
# Frog       - 89.3
# Horse      - 75.0
# Ship       - 85.5
# Truck      - 80.0
#
# Backdoor ASR 5.3
#
#  | Global training round : 19/100 |
#
# Average of peers' local losses: 0.347595
#
# Average test loss: 1.0009, Test accuracy: 7023/10000 (70.23%)
#
# Class      - Accuracy
# Plane      - 78.0
# Car        - 79.2
# Bird       - 47.7
# Cat        - 32.4
# Deer       - 72.9
# Dog        - 68.7
# Frog       - 89.1
# Horse      - 73.3
# Ship       - 82.5
# Truck      - 78.5
#
# Backdoor ASR 4.9
#
#  | Global training round : 20/100 |
#
# Average of peers' local losses: 0.328578
#
# Average test loss: 1.0175, Test accuracy: 7048/10000 (70.48%)
#
# Class      - Accuracy
# Plane      - 75.7
# Car        - 76.9
# Bird       - 48.0
# Cat        - 33.7
# Deer       - 72.6
# Dog        - 68.2
# Frog       - 89.6
# Horse      - 73.4
# Ship       - 86.6
# Truck      - 80.1
#
# Backdoor ASR 6.0
#
#  | Global training round : 21/100 |
#
# Average of peers' local losses: 0.319646
#
# Average test loss: 0.9974, Test accuracy: 7084/10000 (70.84%)
#
# Class      - Accuracy
# Plane      - 78.0
# Car        - 78.7
# Bird       - 53.5
# Cat        - 31.8
# Deer       - 68.5
# Dog        - 66.4
# Frog       - 89.2
# Horse      - 75.2
# Ship       - 85.9
# Truck      - 81.2
#
# Backdoor ASR 4.8
#
#  | Global training round : 22/100 |
#
# Average of peers' local losses: 0.309669
#
# Average test loss: 0.9755, Test accuracy: 7125/10000 (71.25%)
#
# Class      - Accuracy
# Plane      - 77.6
# Car        - 77.4
# Bird       - 50.2
# Cat        - 40.4
# Deer       - 69.7
# Dog        - 65.6
# Frog       - 88.4
# Horse      - 75.9
# Ship       - 84.8
# Truck      - 82.5
#
# Backdoor ASR 5.6
#
#  | Global training round : 23/100 |
#
# Average of peers' local losses: 0.291960
#
# Average test loss: 1.0066, Test accuracy: 7151/10000 (71.51%)
#
# Class      - Accuracy
# Plane      - 78.6
# Car        - 82.2
# Bird       - 50.1
# Cat        - 31.4
# Deer       - 70.2
# Dog        - 72.3
# Frog       - 87.8
# Horse      - 77.0
# Ship       - 84.6
# Truck      - 80.9
# Backdoor ASR 4.3
#
#  | Global training round : 24/100 |
#
# Average of peers' local losses: 0.282660
#
# Average test loss: 0.9893, Test accuracy: 7186/10000 (71.86%)
#
# Class      - Accuracy
# Plane      - 78.7
# Car        - 81.7
# Bird       - 51.6
# Cat        - 36.5
# Deer       - 72.6
# Dog        - 66.6
# Frog       - 88.6
# Horse      - 76.5
# Ship       - 84.9
# Truck      - 80.9
#
# Backdoor ASR 6.0
#
#  | Global training round : 25/100 |
#
# Average of peers' local losses: 0.274911
#
# Average test loss: 0.9818, Test accuracy: 7201/10000 (72.01%)
#
# Class      - Accuracy
# Plane      - 78.8
# Car        - 80.4
# Bird       - 49.3
# Cat        - 39.3
# Deer       - 72.7
# Dog        - 66.7
# Frog       - 90.1
# Horse      - 77.0
# Ship       - 85.8
# Truck      - 80.0
#
# Backdoor ASR 6.8
#
#  | Global training round : 26/100 |
#
# Average of peers' local losses: 0.262424
#
# Average test loss: 1.0345, Test accuracy: 7163/10000 (71.63%)
#
# Class      - Accuracy
# Plane      - 76.7
# Car        - 80.9
# Bird       - 51.7
# Cat        - 30.1
# Deer       - 72.9
# Dog        - 69.0
# Frog       - 91.2
# Horse      - 76.9
# Ship       - 87.2
# Truck      - 79.7
#
# Backdoor ASR 6.5
#
#  | Global training round : 27/100 |
#
# Average of peers' local losses: 0.259441
#
# Average test loss: 1.0181, Test accuracy: 7161/10000 (71.61%)
#
# Class      - Accuracy
# Plane      - 77.9
# Car        - 78.4
# Bird       - 50.5
# Cat        - 37.0
# Deer       - 72.1
# Dog        - 67.8
# Frog       - 90.8
# Horse      - 73.6
# Ship       - 86.5
# Truck      - 81.5
#
# Backdoor ASR 8.0
#
#  | Global training round : 28/100 |
#
# Average of peers' local losses: 0.249366
#
# Average test loss: 1.0081, Test accuracy: 7175/10000 (71.75%)
#
# Class      - Accuracy
# Plane      - 75.9
# Car        - 79.9
# Bird       - 53.0
# Cat        - 34.9
# Deer       - 72.5
# Dog        - 67.7
# Frog       - 89.6
# Horse      - 76.5
# Ship       - 86.8
# Truck      - 80.7
#
# Backdoor ASR 7.7
#
#  | Global training round : 29/100 |
#
# Average of peers' local losses: 0.237590
#
# Average test loss: 0.9918, Test accuracy: 7212/10000 (72.12%)
#
# Class      - Accuracy
# Plane      - 79.6
# Car        - 82.2
# Bird       - 51.0
# Cat        - 36.5
# Deer       - 71.0
# Dog        - 67.0
# Frog       - 91.2
# Horse      - 78.2
# Ship       - 85.7
# Truck      - 78.8
#
# Backdoor ASR 8.9
#
#  | Global training round : 30/100 |
#
# Average of peers' local losses: 0.228847
#
# Average test loss: 0.9598, Test accuracy: 7275/10000 (72.75%)
#
# Class      - Accuracy
# Plane      - 80.0
# Car        - 82.1
# Bird       - 54.2
# Cat        - 42.8
# Deer       - 75.7
# Dog        - 66.5
# Frog       - 86.9
# Horse      - 75.8
# Ship       - 84.5
# Truck      - 79.0
#
# Backdoor ASR 14.6
#
#  | Global training round : 31/100 |
#
# Average of peers' local losses: 0.224620
#
# Average test loss: 0.9930, Test accuracy: 7238/10000 (72.38%)
#
# Class      - Accuracy
# Plane      - 79.1
# Car        - 81.7
# Bird       - 52.8
# Cat        - 37.9
# Deer       - 75.6
# Dog        - 66.4
# Frog       - 88.8
# Horse      - 75.0
# Ship       - 87.1
# Truck      - 79.4
#
# Backdoor ASR 10.1
#
#  | Global training round : 32/100 |
#
# Average of peers' local losses: 0.216316
#
# Average test loss: 0.9794, Test accuracy: 7211/10000 (72.11%)
#
# Class      - Accuracy
# Plane      - 77.9
# Car        - 79.5
# Bird       - 53.2
# Cat        - 39.0
# Deer       - 70.9
# Dog        - 68.6
# Frog       - 88.1
# Horse      - 76.3
# Ship       - 85.9
# Truck      - 81.7
#
# Backdoor ASR 9.7
#
#  | Global training round : 33/100 |
#
# Average of peers' local losses: 0.206125
#
# Average test loss: 0.9861, Test accuracy: 7228/10000 (72.28%)
#
# Class      - Accuracy
# Plane      - 79.3
# Car        - 80.9
# Bird       - 53.0
# Cat        - 38.9
# Deer       - 74.9
# Dog        - 64.8
# Frog       - 89.1
# Horse      - 76.4
# Ship       - 85.2
# Truck      - 80.3
#
# Backdoor ASR 11.2
#
#  | Global training round : 34/100 |
#
# Average of peers' local losses: 0.208413
#
# Average test loss: 0.9747, Test accuracy: 7234/10000 (72.34%)
#
# Class      - Accuracy
# Plane      - 79.6
# Car        - 81.6
# Bird       - 50.4
# Cat        - 39.3
# Deer       - 74.8
# Dog        - 66.8
# Frog       - 88.9
# Horse      - 75.8
# Ship       - 86.2
# Truck      - 80.0
#
# Backdoor ASR 12.5
#
#  | Global training round : 35/100 |
#
# Average of peers' local losses: 0.193454
#
# Average test loss: 0.9986, Test accuracy: 7236/10000 (72.36%)
#
# Class      - Accuracy
# Plane      - 79.4
# Car        - 79.9
# Bird       - 55.2
# Cat        - 40.2
# Deer       - 70.3
# Dog        - 65.8
# Frog       - 89.7
# Horse      - 76.0
# Ship       - 86.8
# Truck      - 80.3
#
# Backdoor ASR 14.3
#
#  | Global training round : 36/100 |
#
# Average of peers' local losses: 0.190524
#
# Average test loss: 1.0200, Test accuracy: 7245/10000 (72.45%)
#
# Class      - Accuracy
# Plane      - 79.0
# Car        - 81.9
# Bird       - 53.6
# Cat        - 36.4
# Deer       - 71.7
# Dog        - 69.7
# Frog       - 88.1
# Horse      - 77.1
# Ship       - 86.2
# Truck      - 80.8
#
# Backdoor ASR 10.6
#
#  | Global training round : 37/100 |
#
# Average of peers' local losses: 0.191071
#
# Average test loss: 1.0023, Test accuracy: 7281/10000 (72.81%)
#
# Class      - Accuracy
# Plane      - 80.5
# Car        - 82.5
# Bird       - 53.4
# Cat        - 38.4
# Deer       - 74.5
# Dog        - 67.8
# Frog       - 88.8
# Horse      - 77.5
# Ship       - 85.8
# Truck      - 78.9
#
# Backdoor ASR 12.0
#
#  | Global training round : 38/100 |
#
# Average of peers' local losses: 0.181858
#
# Average test loss: 1.0052, Test accuracy: 7236/10000 (72.36%)
#
# Class      - Accuracy
# Plane      - 77.3
# Car        - 79.8
# Bird       - 54.7
# Cat        - 38.0
# Deer       - 71.6
# Dog        - 68.5
# Frog       - 89.5
# Horse      - 76.5
# Ship       - 87.6
# Truck      - 80.1
#
# Backdoor ASR 14.8
#
#  | Global training round : 39/100 |
#
# Average of peers' local losses: 0.181587
#
# Average test loss: 0.9786, Test accuracy: 7268/10000 (72.68%)
#
# Class      - Accuracy
# Plane      - 78.7
# Car        - 81.5
# Bird       - 54.0
# Cat        - 45.2
# Deer       - 69.5
# Dog        - 66.6
# Frog       - 86.2
# Horse      - 76.9
# Ship       - 86.8
# Truck      - 81.4
#
# Backdoor ASR 16.6
#
#  | Global training round : 40/100 |
#
# Average of peers' local losses: 0.162845
#
# Average test loss: 1.0165, Test accuracy: 7263/10000 (72.63%)
#
# Class      - Accuracy
# Plane      - 81.6
# Car        - 79.1
# Bird       - 53.7
# Cat        - 39.9
# Deer       - 72.9
# Dog        - 67.3
# Frog       - 87.7
# Horse      - 77.0
# Ship       - 86.3
# Truck      - 80.8
#
# Backdoor ASR 24.0
#
#  | Global training round : 41/100 |
#
# Average of peers' local losses: 0.177672
#
# Average test loss: 0.9582, Test accuracy: 7345/10000 (73.45%)
#
# Class      - Accuracy
# Plane      - 80.9
# Car        - 83.7
# Bird       - 57.7
# Cat        - 43.5
# Deer       - 73.8
# Dog        - 67.1
# Frog       - 85.6
# Horse      - 77.0
# Ship       - 84.9
# Truck      - 80.3
#
# Backdoor ASR 24.8
#
#  | Global training round : 42/100 |
#
# Average of peers' local losses: 0.152270
#
# Average test loss: 1.0168, Test accuracy: 7277/10000 (72.77%)
#
# Class      - Accuracy
# Plane      - 78.0
# Car        - 80.5
# Bird       - 58.5
# Cat        - 42.6
# Deer       - 68.5
# Dog        - 67.3
# Frog       - 89.0
# Horse      - 77.0
# Ship       - 86.5
# Truck      - 79.8
#
# Backdoor ASR 33.1
#
#  | Global training round : 43/100 |
#
# Average of peers' local losses: 0.172591
#
# Average test loss: 0.9904, Test accuracy: 7306/10000 (73.06%)
#
# Class      - Accuracy
# Plane      - 79.4
# Car        - 82.4
# Bird       - 58.6
# Cat        - 40.3
# Deer       - 69.3
# Dog        - 69.3
# Frog       - 88.2
# Horse      - 77.4
# Ship       - 86.1
# Truck      - 79.6
#
# Backdoor ASR 32.2
#
#  | Global training round : 44/100 |
#
# Average of peers' local losses: 0.136676
#
# Average test loss: 1.0567, Test accuracy: 7313/10000 (73.13%)
#
# Class      - Accuracy
# Plane      - 79.0
# Car        - 82.6
# Bird       - 55.8
# Cat        - 41.9
# Deer       - 72.2
# Dog        - 67.1
# Frog       - 88.2
# Horse      - 76.0
# Ship       - 87.0
# Truck      - 81.5
#
# Backdoor ASR 29.5
#
#  | Global training round : 45/100 |
#
# Average of peers' local losses: 0.170911
#
# Average test loss: 0.9838, Test accuracy: 7282/10000 (72.82%)
#
# Class      - Accuracy
# Plane      - 78.6
# Car        - 79.6
# Bird       - 54.7
# Cat        - 42.7
# Deer       - 74.7
# Dog        - 62.3
# Frog       - 89.0
# Horse      - 76.8
# Ship       - 88.1
# Truck      - 81.7
#
# Backdoor ASR 26.3
#
#  | Global training round : 46/100 |
#
# Average of peers' local losses: 0.147966
#
# Average test loss: 1.0351, Test accuracy: 7318/10000 (73.18%)
#
# Class      - Accuracy
# Plane      - 79.5
# Car        - 84.1
# Bird       - 55.6
# Cat        - 40.0
# Deer       - 75.2
# Dog        - 67.9
# Frog       - 87.1
# Horse      - 75.9
# Ship       - 87.1
# Truck      - 79.4
# Backdoor ASR 26.3
#
#  | Global training round : 47/100 |
#
# Average of peers' local losses: 0.141836
#
# Average test loss: 1.0210, Test accuracy: 7293/10000 (72.93%)
#
# Class      - Accuracy
# Plane      - 81.3
# Car        - 80.1
# Bird       - 54.2
# Cat        - 44.8
# Deer       - 73.1
# Dog        - 63.9
# Frog       - 88.2
# Horse      - 77.3
# Ship       - 85.0
# Truck      - 81.4
#
# Backdoor ASR 31.3
#
#  | Global training round : 48/100 |
#
# Average of peers' local losses: 0.148816
#
# Average test loss: 1.0303, Test accuracy: 7301/10000 (73.01%)
#
# Class      - Accuracy
# Plane      - 77.7
# Car        - 83.0
# Bird       - 56.7
# Cat        - 39.1
# Deer       - 72.4
# Dog        - 66.8
# Frog       - 88.6
# Horse      - 77.9
# Ship       - 88.5
# Truck      - 79.4
#
# Backdoor ASR 26.5
#
#  | Global training round : 49/100 |
#
# Average of peers' local losses: 0.161276
#
# Average test loss: 0.9960, Test accuracy: 7295/10000 (72.95%)
#
# Class      - Accuracy
# Plane      - 80.1
# Car        - 81.9
# Bird       - 51.6
# Cat        - 41.0
# Deer       - 72.6
# Dog        - 70.8
# Frog       - 89.0
# Horse      - 76.0
# Ship       - 87.8
# Truck      - 78.7
#
# Backdoor ASR 23.2
#
#  | Global training round : 50/100 |
#
# Average of peers' local losses: 0.126789
#
# Average test loss: 1.0211, Test accuracy: 7318/10000 (73.18%)
#
# Class      - Accuracy
# Plane      - 79.0
# Car        - 83.1
# Bird       - 58.6
# Cat        - 45.5
# Deer       - 69.5
# Dog        - 68.1
# Frog       - 85.6
# Horse      - 76.6
# Ship       - 85.2
# Truck      - 80.6
#
# Backdoor ASR 35.7
#
#  | Global training round : 51/100 |
#
# Average of peers' local losses: 0.153380
#
# Average test loss: 0.9880, Test accuracy: 7296/10000 (72.96%)
#
# Class      - Accuracy
# Plane      - 80.3
# Car        - 83.4
# Bird       - 55.4
# Cat        - 40.1
# Deer       - 72.3
# Dog        - 65.1
# Frog       - 88.4
# Horse      - 77.7
# Ship       - 85.6
# Truck      - 81.3
#
# Backdoor ASR 26.7
#
#  | Global training round : 52/100 |
#
# Average of peers' local losses: 0.126354
#
# Average test loss: 1.0149, Test accuracy: 7320/10000 (73.20%)
#
# Class      - Accuracy
# Plane      - 78.6
# Car        - 83.7
# Bird       - 59.4
# Cat        - 43.8
# Deer       - 69.4
# Dog        - 66.2
# Frog       - 85.4
# Horse      - 78.6
# Ship       - 85.1
# Truck      - 81.8
#
# Backdoor ASR 39.4
#
#  | Global training round : 53/100 |
#
# Average of peers' local losses: 0.143577
#
# Average test loss: 1.0289, Test accuracy: 7341/10000 (73.41%)
#
# Class      - Accuracy
# Plane      - 79.4
# Car        - 83.4
# Bird       - 56.7
# Cat        - 40.2
# Deer       - 72.2
# Dog        - 69.5
# Frog       - 89.4
# Horse      - 75.9
# Ship       - 87.2
# Truck      - 80.2
#
# Backdoor ASR 32.0
#
#  | Global training round : 54/100 |
#
# Average of peers' local losses: 0.161924
#
# Average test loss: 0.9637, Test accuracy: 7293/10000 (72.93%)
#
# Class      - Accuracy
# Plane      - 78.1
# Car        - 81.7
# Bird       - 55.3
# Cat        - 41.5
# Deer       - 74.9
# Dog        - 62.6
# Frog       - 89.0
# Horse      - 76.9
# Ship       - 88.5
# Truck      - 80.8
#
# Backdoor ASR 24.6
#
#  | Global training round : 55/100 |
#
# Average of peers' local losses: 0.114351
#
# Average test loss: 1.0917, Test accuracy: 7292/10000 (72.92%)
#
# Class      - Accuracy
# Plane      - 78.8
# Car        - 79.5
# Bird       - 54.6
# Cat        - 41.9
# Deer       - 70.4
# Dog        - 68.1
# Frog       - 89.1
# Horse      - 77.7
# Ship       - 86.5
# Truck      - 82.6
#
# Backdoor ASR 33.6
#
#  | Global training round : 56/100 |
#
# Average of peers' local losses: 0.154606
#
# Average test loss: 1.0133, Test accuracy: 7315/10000 (73.15%)
#
# Class      - Accuracy
# Plane      - 80.5
# Car        - 85.1
# Bird       - 53.5
# Cat        - 39.6
# Deer       - 74.6
# Dog        - 69.7
# Frog       - 87.6
# Horse      - 76.5
# Ship       - 86.8
# Truck      - 77.6
#
# Backdoor ASR 28.8
#
#  | Global training round : 57/100 |
#
# Average of peers' local losses: 0.125402
#
# Average test loss: 1.0198, Test accuracy: 7345/10000 (73.45%)
#
# Class      - Accuracy
# Plane      - 80.1
# Car        - 84.1
# Bird       - 59.1
# Cat        - 42.6
# Deer       - 73.5
# Dog        - 65.9
# Frog       - 85.9
# Horse      - 78.3
# Ship       - 86.6
# Truck      - 78.4
#
# Backdoor ASR 44.3
#
#  | Global training round : 58/100 |
#
# Average of peers' local losses: 0.140869
#
# Average test loss: 0.9937, Test accuracy: 7309/10000 (73.09%)
#
# Class      - Accuracy
# Plane      - 79.0
# Car        - 82.6
# Bird       - 58.7
# Cat        - 43.5
# Deer       - 71.2
# Dog        - 66.2
# Frog       - 87.0
# Horse      - 77.0
# Ship       - 86.5
# Truck      - 79.2
#
# Backdoor ASR 48.6
#
#  | Global training round : 59/100 |
#
# Average of peers' local losses: 0.135502
#
# Average test loss: 0.9863, Test accuracy: 7345/10000 (73.45%)
#
# Class      - Accuracy
# Plane      - 79.7
# Car        - 84.4
# Bird       - 61.8
# Cat        - 42.3
# Deer       - 71.3
# Dog        - 66.7
# Frog       - 85.9
# Horse      - 76.3
# Ship       - 86.6
# Truck      - 79.5
#
# Backdoor ASR 46.5
#
#  | Global training round : 60/100 |
#
# Average of peers' local losses: 0.117800
#
# Average test loss: 1.0263, Test accuracy: 7354/10000 (73.54%)
#
# Class      - Accuracy
# Plane      - 78.7
# Car        - 81.9
# Bird       - 62.5
# Cat        - 41.9
# Deer       - 71.6
# Dog        - 66.7
# Frog       - 85.5
# Horse      - 77.6
# Ship       - 86.9
# Truck      - 82.1
#
# Backdoor ASR 51.7
#
#  | Global training round : 61/100 |
#
# Average of peers' local losses: 0.139788
#
# Average test loss: 0.9739, Test accuracy: 7377/10000 (73.77%)
#
# Class      - Accuracy
# Plane      - 79.4
# Car        - 84.4
# Bird       - 60.9
# Cat        - 48.5
# Deer       - 71.3
# Dog        - 63.2
# Frog       - 87.0
# Horse      - 76.7
# Ship       - 86.9
# Truck      - 79.4
#
# Backdoor ASR 48.0
#
#  | Global training round : 62/100 |
#
# Average of peers' local losses: 0.122672
#
# Average test loss: 1.0350, Test accuracy: 7375/10000 (73.75%)
#
# Class      - Accuracy
# Plane      - 79.4
# Car        - 84.9
# Bird       - 56.8
# Cat        - 41.2
# Deer       - 72.9
# Dog        - 71.5
# Frog       - 85.4
# Horse      - 79.0
# Ship       - 86.2
# Truck      - 80.2
#
# Backdoor ASR 47.6
#
#  | Global training round : 63/100 |
#
# Average of peers' local losses: 0.143687
#
# Average test loss: 1.0171, Test accuracy: 7314/10000 (73.14%)
#
# Class      - Accuracy
# Plane      - 79.7
# Car        - 81.1
# Bird       - 57.7
# Cat        - 40.9
# Deer       - 70.0
# Dog        - 65.5
# Frog       - 90.4
# Horse      - 76.3
# Ship       - 86.7
# Truck      - 83.1
#
# Backdoor ASR 37.7
#
#  | Global training round : 64/100 |
#
# Average of peers' local losses: 0.116382
#
# Average test loss: 1.0240, Test accuracy: 7371/10000 (73.71%)
#
# Class      - Accuracy
# Plane      - 79.5
# Car        - 83.6
# Bird       - 63.3
# Cat        - 44.7
# Deer       - 69.9
# Dog        - 67.9
# Frog       - 86.8
# Horse      - 76.0
# Ship       - 85.2
# Truck      - 80.2
#
# Backdoor ASR 49.2
#
#  | Global training round : 65/100 |
#
# Average of peers' local losses: 0.142062
#
# Average test loss: 0.9968, Test accuracy: 7346/10000 (73.46%)
#
# Class      - Accuracy
# Plane      - 80.8
# Car        - 84.9
# Bird       - 56.4
# Cat        - 38.9
# Deer       - 74.7
# Dog        - 67.1
# Frog       - 87.1
# Horse      - 77.2
# Ship       - 87.5
# Truck      - 80.0
#
# Backdoor ASR 42.7
#
#  | Global training round : 66/100 |
#
# Average of peers' local losses: 0.117759
#
# Average test loss: 1.0249, Test accuracy: 7360/10000 (73.60%)
#
# Class      - Accuracy
# Plane      - 79.5
# Car        - 83.9
# Bird       - 59.7
# Cat        - 46.7
# Deer       - 70.0
# Dog        - 64.4
# Frog       - 87.3
# Horse      - 78.6
# Ship       - 84.9
# Truck      - 81.0
#
# Backdoor ASR 51.4
#
#  | Global training round : 67/100 |
#
# Average of peers' local losses: 0.142966
#
# Average test loss: 0.9525, Test accuracy: 7371/10000 (73.71%)
#
# Class      - Accuracy
# Plane      - 79.2
# Car        - 82.1
# Bird       - 54.7
# Cat        - 46.1
# Deer       - 73.9
# Dog        - 67.6
# Frog       - 87.7
# Horse      - 78.2
# Ship       - 85.3
# Truck      - 82.3
#
# Backdoor ASR 46.1
#
#  | Global training round : 68/100 |
#
# Average of peers' local losses: 0.114441
#
# Average test loss: 1.0224, Test accuracy: 7364/10000 (73.64%)
#
# Class      - Accuracy
# Plane      - 78.5
# Car        - 82.8
# Bird       - 60.4
# Cat        - 44.8
# Deer       - 71.2
# Dog        - 67.5
# Frog       - 87.3
# Horse      - 76.7
# Ship       - 87.0
# Truck      - 80.2
#
# Backdoor ASR 57.8
#
#  | Global training round : 69/100 |
#
# Average of peers' local losses: 0.146580
#
# Average test loss: 0.9571, Test accuracy: 7333/10000 (73.33%)
#
# Class      - Accuracy
# Plane      - 78.4
# Car        - 83.2
# Bird       - 58.3
# Cat        - 37.5
# Deer       - 71.5
# Dog        - 68.8
# Frog       - 89.0
# Horse      - 80.1
# Ship       - 86.4
# Truck      - 80.1
# Backdoor ASR 43.3
#
#  | Global training round : 70/100 |
#
# Average of peers' local losses: 0.131502
#
# Average test loss: 0.9641, Test accuracy: 7396/10000 (73.96%)
#
# Class      - Accuracy
# Plane      - 79.5
# Car        - 84.8
# Bird       - 58.1
# Cat        - 43.3
# Deer       - 73.5
# Dog        - 69.7
# Frog       - 88.9
# Horse      - 78.1
# Ship       - 84.4
# Truck      - 79.3
#
# Backdoor ASR 43.8
#
#  | Global training round : 71/100 |
#
# Average of peers' local losses: 0.120784
#
# Average test loss: 0.9941, Test accuracy: 7380/10000 (73.80%)
#
# Class      - Accuracy
# Plane      - 80.3
# Car        - 82.6
# Bird       - 62.4
# Cat        - 45.8
# Deer       - 72.2
# Dog        - 66.8
# Frog       - 85.4
# Horse      - 76.8
# Ship       - 85.1
# Truck      - 80.6
#
# Backdoor ASR 51.9
#
#  | Global training round : 72/100 |
#
# Average of peers' local losses: 0.143879
#
# Average test loss: 0.9618, Test accuracy: 7343/10000 (73.43%)
#
# Class      - Accuracy
# Plane      - 78.7
# Car        - 81.6
# Bird       - 58.8
# Cat        - 39.4
# Deer       - 71.3
# Dog        - 68.2
# Frog       - 89.1
# Horse      - 78.0
# Ship       - 86.9
# Truck      - 82.3
#
# Backdoor ASR 39.9
#
#  | Global training round : 73/100 |
#
# Average of peers' local losses: 0.115799
#
# Average test loss: 1.0050, Test accuracy: 7391/10000 (73.91%)
#
# Class      - Accuracy
# Plane      - 78.2
# Car        - 84.3
# Bird       - 60.6
# Cat        - 44.3
# Deer       - 73.1
# Dog        - 68.1
# Frog       - 85.1
# Horse      - 78.0
# Ship       - 86.9
# Truck      - 80.5
#
# Backdoor ASR 51.0
#
#  | Global training round : 74/100 |
#
# Average of peers' local losses: 0.141450
#
# Average test loss: 0.9698, Test accuracy: 7345/10000 (73.45%)
#
# Class      - Accuracy
# Plane      - 79.5
# Car        - 84.9
# Bird       - 55.0
# Cat        - 39.1
# Deer       - 74.4
# Dog        - 69.3
# Frog       - 88.2
# Horse      - 78.0
# Ship       - 88.0
# Truck      - 78.1
#
# Backdoor ASR 48.2
#
#  | Global training round : 75/100 |
#
# Average of peers' local losses: 0.125539
#
# Average test loss: 0.9672, Test accuracy: 7355/10000 (73.55%)
#
# Class      - Accuracy
# Plane      - 80.3
# Car        - 82.8
# Bird       - 59.1
# Cat        - 45.7
# Deer       - 69.1
# Dog        - 69.7
# Frog       - 87.0
# Horse      - 76.1
# Ship       - 84.1
# Truck      - 81.6
#
# Backdoor ASR 55.0
#
#  | Global training round : 76/100 |
#
# Average of peers' local losses: 0.128259
#
# Average test loss: 0.9694, Test accuracy: 7367/10000 (73.67%)
#
# Class      - Accuracy
# Plane      - 80.3
# Car        - 86.6
# Bird       - 61.2
# Cat        - 45.6
# Deer       - 71.6
# Dog        - 67.1
# Frog       - 85.7
# Horse      - 75.2
# Ship       - 84.7
# Truck      - 78.7
#
# Backdoor ASR 55.3
#
#  | Global training round : 77/100 |
#
# Average of peers' local losses: 0.138380
#
# Average test loss: 0.9723, Test accuracy: 7372/10000 (73.72%)
#
# Class      - Accuracy
# Plane      - 79.4
# Car        - 84.5
# Bird       - 55.9
# Cat        - 37.1
# Deer       - 74.0
# Dog        - 70.8
# Frog       - 87.2
# Horse      - 80.7
# Ship       - 86.6
# Truck      - 81.0
#
# Backdoor ASR 52.0
#
#  | Global training round : 78/100 |
#
# Average of peers' local losses: 0.124412
#
# Average test loss: 0.9665, Test accuracy: 7372/10000 (73.72%)
#
# Class      - Accuracy
# Plane      - 81.0
# Car        - 83.4
# Bird       - 59.7
# Cat        - 46.5
# Deer       - 70.3
# Dog        - 66.8
# Frog       - 85.6
# Horse      - 77.0
# Ship       - 85.3
# Truck      - 81.6
#
# Backdoor ASR 58.3
#
#  | Global training round : 79/100 |
#
# Average of peers' local losses: 0.129189
#
# Average test loss: 0.9396, Test accuracy: 7419/10000 (74.19%)
#
# Class      - Accuracy
# Plane      - 81.6
# Car        - 86.2
# Bird       - 60.2
# Cat        - 45.0
# Deer       - 73.4
# Dog        - 67.0
# Frog       - 87.3
# Horse      - 77.6
# Ship       - 85.4
# Truck      - 78.2
#
# Backdoor ASR 57.2
#
#  | Global training round : 80/100 |
#
# Average of peers' local losses: 0.131445
#
# Average test loss: 0.9589, Test accuracy: 7417/10000 (74.17%)
#
# Class      - Accuracy
# Plane      - 80.8
# Car        - 83.4
# Bird       - 58.7
# Cat        - 45.7
# Deer       - 73.2
# Dog        - 68.7
# Frog       - 86.9
# Horse      - 76.5
# Ship       - 86.2
# Truck      - 81.6
#
# Backdoor ASR 51.8
#
#  | Global training round : 81/100 |
#
# Average of peers' local losses: 0.139379
#
# Average test loss: 0.9341, Test accuracy: 7426/10000 (74.26%)
#
# Class      - Accuracy
# Plane      - 82.0
# Car        - 84.0
# Bird       - 59.9
# Cat        - 48.5
# Deer       - 73.9
# Dog        - 68.5
# Frog       - 84.2
# Horse      - 77.0
# Ship       - 83.4
# Truck      - 81.2
#
# Backdoor ASR 53.1
#
#  | Global training round : 82/100 |
#
# Average of peers' local losses: 0.129140
#
# Average test loss: 0.9446, Test accuracy: 7389/10000 (73.89%)
#
# Class      - Accuracy
# Plane      - 82.0
# Car        - 84.1
# Bird       - 61.5
# Cat        - 46.6
# Deer       - 73.2
# Dog        - 65.6
# Frog       - 85.7
# Horse      - 77.3
# Ship       - 82.8
# Truck      - 80.1
#
# Backdoor ASR 58.3
#
#  | Global training round : 83/100 |
#
# Average of peers' local losses: 0.149432
#
# Average test loss: 0.9030, Test accuracy: 7389/10000 (73.89%)
#
# Class      - Accuracy
# Plane      - 78.3
# Car        - 83.6
# Bird       - 61.3
# Cat        - 42.2
# Deer       - 72.5
# Dog        - 69.4
# Frog       - 87.7
# Horse      - 77.1
# Ship       - 87.1
# Truck      - 79.7
#
# Backdoor ASR 55.5
#
#  | Global training round : 84/100 |
#
# Average of peers' local losses: 0.120166
#
# Average test loss: 0.9727, Test accuracy: 7373/10000 (73.73%)
#
# Class      - Accuracy
# Plane      - 80.1
# Car        - 84.5
# Bird       - 55.4
# Cat        - 40.3
# Deer       - 75.4
# Dog        - 67.9
# Frog       - 87.8
# Horse      - 81.2
# Ship       - 84.4
# Truck      - 80.3
#
# Backdoor ASR 59.9
#
#  | Global training round : 85/100 |
#
# Average of peers' local losses: 0.128286
#
# Average test loss: 0.9339, Test accuracy: 7413/10000 (74.13%)
#
# Class      - Accuracy
# Plane      - 80.5
# Car        - 85.1
# Bird       - 62.4
# Cat        - 47.5
# Deer       - 73.3
# Dog        - 64.0
# Frog       - 86.5
# Horse      - 77.8
# Ship       - 84.9
# Truck      - 79.3
#
# Backdoor ASR 58.0
#
#  | Global training round : 86/100 |
#
# Average of peers' local losses: 0.133950
#
# Average test loss: 0.9267, Test accuracy: 7434/10000 (74.34%)
#
# Class      - Accuracy
# Plane      - 80.0
# Car        - 84.6
# Bird       - 60.5
# Cat        - 45.7
# Deer       - 71.7
# Dog        - 69.5
# Frog       - 86.2
# Horse      - 78.3
# Ship       - 87.0
# Truck      - 79.9
#
# Backdoor ASR 58.1
#
#  | Global training round : 87/100 |
#
# Average of peers' local losses: 0.114491
#
# Average test loss: 0.9764, Test accuracy: 7405/10000 (74.05%)
#
# Class      - Accuracy
# Plane      - 81.1
# Car        - 84.2
# Bird       - 62.4
# Cat        - 47.5
# Deer       - 72.9
# Dog        - 66.2
# Frog       - 84.9
# Horse      - 76.1
# Ship       - 84.6
# Truck      - 80.6
#
# Backdoor ASR 64.6
#
#  | Global training round : 88/100 |
#
# Average of peers' local losses: 0.142008
#
# Average test loss: 0.9003, Test accuracy: 7421/10000 (74.21%)
#
# Class      - Accuracy
# Plane      - 79.9
# Car        - 85.0
# Bird       - 60.9
# Cat        - 46.3
# Deer       - 71.7
# Dog        - 68.6
# Frog       - 85.6
# Horse      - 77.8
# Ship       - 85.3
# Truck      - 81.0
#
# Backdoor ASR 57.9
#
#  | Global training round : 89/100 |
#
# Average of peers' local losses: 0.128776
#
# Average test loss: 0.9481, Test accuracy: 7379/10000 (73.79%)
#
# Class      - Accuracy
# Plane      - 81.4
# Car        - 83.8
# Bird       - 62.6
# Cat        - 47.1
# Deer       - 70.7
# Dog        - 65.9
# Frog       - 85.7
# Horse      - 75.9
# Ship       - 85.3
# Truck      - 79.5
#
# Backdoor ASR 63.2
#
#  | Global training round : 90/100 |
#
# Average of peers' local losses: 0.126198
#
# Average test loss: 0.9495, Test accuracy: 7365/10000 (73.65%)
#
# Class      - Accuracy
# Plane      - 81.8
# Car        - 83.0
# Bird       - 65.2
# Cat        - 44.5
# Deer       - 70.8
# Dog        - 65.3
# Frog       - 83.3
# Horse      - 78.0
# Ship       - 84.7
# Truck      - 79.9
#
# Backdoor ASR 63.7
#
#  | Global training round : 91/100 |
#
# Average of peers' local losses: 0.162975
#
# Average test loss: 0.8991, Test accuracy: 7339/10000 (73.39%)
#
# Class      - Accuracy
# Plane      - 80.4
# Car        - 82.6
# Bird       - 56.8
# Cat        - 37.8
# Deer       - 72.4
# Dog        - 66.3
# Frog       - 90.7
# Horse      - 78.3
# Ship       - 86.9
# Truck      - 81.7
#
# Backdoor ASR 50.7
#
#  | Global training round : 92/100 |
#
# Average of peers' local losses: 0.114997
#
# Average test loss: 0.9710, Test accuracy: 7363/10000 (73.63%)
#
# Class      - Accuracy
# Plane      - 80.9
# Car        - 84.1
# Bird       - 62.0
# Cat        - 38.0
# Deer       - 73.3
# Dog        - 69.7
# Frog       - 84.8
# Horse      - 80.0
# Ship       - 83.7
# Truck      - 79.8
# Backdoor ASR 57.3
#
#  | Global training round : 93/100 |
#
# Average of peers' local losses: 0.117554
#
# Average test loss: 0.9661, Test accuracy: 7407/10000 (74.07%)
#
# Class      - Accuracy
# Plane      - 81.4
# Car        - 84.9
# Bird       - 62.3
# Cat        - 46.8
# Deer       - 73.0
# Dog        - 65.2
# Frog       - 85.6
# Horse      - 77.0
# Ship       - 85.2
# Truck      - 79.3
#
# Backdoor ASR 61.6
#
#  | Global training round : 94/100 |
#
# Average of peers' local losses: 0.129335
#
# Average test loss: 0.9192, Test accuracy: 7388/10000 (73.88%)
#
# Class      - Accuracy
# Plane      - 79.6
# Car        - 85.0
# Bird       - 63.9
# Cat        - 46.6
# Deer       - 72.0
# Dog        - 66.4
# Frog       - 83.3
# Horse      - 76.3
# Ship       - 86.5
# Truck      - 79.2
#
# Backdoor ASR 58.2
#
#  | Global training round : 95/100 |
#
# Average of peers' local losses: 0.145141
#
# Average test loss: 0.9193, Test accuracy: 7378/10000 (73.78%)
#
# Class      - Accuracy
# Plane      - 81.2
# Car        - 86.9
# Bird       - 56.1
# Cat        - 37.2
# Deer       - 75.1
# Dog        - 67.9
# Frog       - 89.2
# Horse      - 80.2
# Ship       - 84.2
# Truck      - 79.8
#
# Backdoor ASR 50.4
#
#  | Global training round : 96/100 |
#
# Average of peers' local losses: 0.137675
#
# Average test loss: 0.9251, Test accuracy: 7380/10000 (73.80%)
#
# Class      - Accuracy
# Plane      - 79.9
# Car        - 81.5
# Bird       - 55.6
# Cat        - 43.7
# Deer       - 72.6
# Dog        - 67.8
# Frog       - 89.7
# Horse      - 78.5
# Ship       - 85.7
# Truck      - 83.0
#
# Backdoor ASR 49.7
#
#  | Global training round : 97/100 |
#
# Average of peers' local losses: 0.111663
#
# Average test loss: 0.9713, Test accuracy: 7417/10000 (74.17%)
#
# Class      - Accuracy
# Plane      - 82.0
# Car        - 83.9
# Bird       - 63.5
# Cat        - 44.5
# Deer       - 71.8
# Dog        - 67.6
# Frog       - 84.5
# Horse      - 78.9
# Ship       - 83.8
# Truck      - 81.2
#
# Backdoor ASR 63.4
#
#  | Global training round : 98/100 |
#
# Average of peers' local losses: 0.145866
#
# Average test loss: 0.9062, Test accuracy: 7382/10000 (73.82%)
#
# Class      - Accuracy
# Plane      - 80.3
# Car        - 83.0
# Bird       - 59.2
# Cat        - 42.2
# Deer       - 70.5
# Dog        - 68.9
# Frog       - 88.0
# Horse      - 78.4
# Ship       - 84.9
# Truck      - 82.8
#
# Backdoor ASR 56.2
#
#  | Global training round : 99/100 |
#
# Average of peers' local losses: 0.129375
#
# Average test loss: 0.9267, Test accuracy: 7436/10000 (74.36%)
#
# Class      - Accuracy
# Plane      - 80.0
# Car        - 83.5
# Bird       - 59.2
# Cat        - 38.9
# Deer       - 75.5
# Dog        - 72.5
# Frog       - 85.0
# Horse      - 80.5
# Ship       - 86.7
# Truck      - 81.8
#
# Backdoor ASR 54.0
#
#  | Global training round : 100/100 |
#
# Average of peers' local losses: 0.106231
#
# Average test loss: 0.9754, Test accuracy: 7443/10000 (74.43%)
#
# Class      - Accuracy
# Plane      - 80.6
# Car        - 85.4
# Bird       - 57.9
# Cat        - 42.5
# Deer       - 77.6
# Dog        - 67.4
# Frog       - 86.3
# Horse      - 80.3
# Ship       - 85.7
# Truck      - 80.6
#
# Backdoor ASR 56.6
# Last 10 updates results
#
# Average test loss: 0.9119, Test accuracy: 7431/10000 (74.31%)
#
# ***********************************************************************************
# Class      - Accuracy
# Plane      - 81.1
# Car        - 84.4
# Bird       - 60.1
# Cat        - 42.0
# Deer       - 74.4
# Dog        - 68.2
# Frog       - 87.0
# Horse      - 78.9
# Ship       - 85.2
# Truck      - 81.8
# Global accuracies:  [10.0, 10.19, 29.42, 48.18, 54.46, 58.35, 61.4, 63.45, 64.64, 65.97, 67.18, 67.55, 68.08, 68.28, 69.26, 69.37, 70.23, 69.63, 70.23, 70.48, 70.84, 71.25, 71.51, 71.86, 72.01, 71.63, 71.61, 71.75, 72.12, 72.75, 72.38, 72.11, 72.28, 72.34, 72.36, 72.45, 72.81, 72.36, 72.68, 72.63, 73.45, 72.77, 73.06, 73.13, 72.82, 73.18, 72.93, 73.01, 72.95, 73.18, 72.96, 73.2, 73.41, 72.93, 72.92, 73.15, 73.45, 73.09, 73.45, 73.54, 73.77, 73.75, 73.14, 73.71, 73.46, 73.6, 73.71, 73.64, 73.33, 73.96, 73.8, 73.43, 73.91, 73.45, 73.55, 73.67, 73.72, 73.72, 74.19, 74.17, 74.26, 73.89, 73.89, 73.73, 74.13, 74.34, 74.05, 74.21, 73.79, 73.65, 73.39, 73.63, 74.07, 73.88, 73.78, 73.8, 74.17, 73.82, 74.36, 74.43, 74.31]
# Class 1 accuracies:  [0.0, 0.0, 7.3, 40.0, 48.1, 66.2, 57.9, 65.8, 68.4, 69.9, 72.3, 70.6, 75.4, 72.3, 78.6, 76.4, 78.3, 75.5, 79.2, 76.9, 78.7, 77.4, 82.2, 81.7, 80.4, 80.9, 78.4, 79.9, 82.2, 82.1, 81.7, 79.5, 80.9, 81.6, 79.9, 81.9, 82.5, 79.8, 81.5, 79.1, 83.7, 80.5, 82.4, 82.6, 79.6, 84.1, 80.1, 83.0, 81.9, 83.1, 83.4, 83.7, 83.4, 81.7, 79.5, 85.1, 84.1, 82.6, 84.4, 81.9, 84.4, 84.9, 81.1, 83.6, 84.9, 83.9, 82.1, 82.8, 83.2, 84.8, 82.6, 81.6, 84.3, 84.9, 82.8, 86.6, 84.5, 83.4, 86.2, 83.4, 84.0, 84.1, 83.6, 84.5, 85.1, 84.6, 84.2, 85.0, 83.8, 83.0, 82.6, 84.1, 84.9, 85.0, 86.9, 81.5, 83.9, 83.0, 83.5, 85.4, 84.4]
# Test loss: [2.3518, 2.2886, 1.8975, 1.4518, 1.2646, 1.1696, 1.0941, 1.074, 1.061, 1.0341, 1.0271, 1.0422, 1.0176, 1.0349, 1.0087, 1.0047, 0.9772, 1.017, 1.0009, 1.0175, 0.9974, 0.9755, 1.0066, 0.9893, 0.9818, 1.0345, 1.0181, 1.0081, 0.9918, 0.9598, 0.993, 0.9794, 0.9861, 0.9747, 0.9986, 1.02, 1.0023, 1.0052, 0.9786, 1.0165, 0.9582, 1.0168, 0.9904, 1.0567, 0.9838, 1.0351, 1.021, 1.0303, 0.996, 1.0211, 0.988, 1.0149, 1.0289, 0.9637, 1.0917, 1.0133, 1.0198, 0.9937, 0.9863, 1.0263, 0.9739, 1.035, 1.0171, 1.024, 0.9968, 1.0249, 0.9525, 1.0224, 0.9571, 0.9641, 0.9941, 0.9618, 1.005, 0.9698, 0.9672, 0.9694, 0.9723, 0.9665, 0.9396, 0.9589, 0.9341, 0.9446, 0.903, 0.9727, 0.9339, 0.9267, 0.9764, 0.9003, 0.9481, 0.9495, 0.8991, 0.971, 0.9661, 0.9192, 0.9193, 0.9251, 0.9713, 0.9062, 0.9267, 0.9754, 0.9119]
# Label-flipping attack succes rate: 0.7
# Backdoor attack succes rate: 56.1
# Average CPU aggregation runtime: 2.0796832919120787
#
# --> End of Experiment.

# %%
RULE = 'foolsgold'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
# --> Loading of CIFAR10 dataset
# Files already downloaded and verified
# Files already downloaded and verified
# --> Dataset has been loaded!
# --> Creating ResNet18 model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: CIFAR10
# Data distribution: MILD_NON_IID
# Aggregation rule: foolsgold
# Attack Type: backdoor
# Attackers Ratio: 10.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/100 [00:00<?, ?it/s]
#  | Global training round : 1/100 |
#
# Average of peers' local losses: 1.752581
#
# Average test loss: 2.3447, Test accuracy: 1000/10000 (10.00%)
#
# Class      - Accuracy
# Plane      - 0.0
# Car        - 0.0
# Bird       - 100.0
# Cat        - 0.0
# Deer       - 0.0
# Dog        - 0.0
# Frog       - 0.0
# Horse      - 0.0
# Ship       - 0.0
# Truck      - 0.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/100 |
#
# Average of peers' local losses: 1.605321
#
# Average test loss: 2.2772, Test accuracy: 1070/10000 (10.70%)
#
# Class      - Accuracy
# Plane      - 6.2
# Car        - 0.0
# Bird       - 99.6
# Cat        - 0.0
# Deer       - 0.0
# Dog        - 1.2
# Frog       - 0.0
# Horse      - 0.0
# Ship       - 0.0
# Truck      - 0.0
#
# Backdoor ASR 2.9
#
#  | Global training round : 3/100 |
#
# Average of peers' local losses: 1.419071
#
# Average test loss: 1.9148, Test accuracy: 3232/10000 (32.32%)
#
# Class      - Accuracy
# Plane      - 62.9
# Car        - 5.6
# Bird       - 61.4
# Cat        - 3.7
# Deer       - 37.9
# Dog        - 34.9
# Frog       - 40.5
# Horse      - 41.2
# Ship       - 1.2
# Truck      - 33.9
#
# Backdoor ASR 24.9
#
#  | Global training round : 4/100 |
#
# Average of peers' local losses: 1.238362
#
# Average test loss: 1.4609, Test accuracy: 4772/10000 (47.72%)
#
# Class      - Accuracy
# Plane      - 46.1
# Car        - 38.6
# Bird       - 38.3
# Cat        - 8.4
# Deer       - 52.8
# Dog        - 56.4
# Frog       - 64.1
# Horse      - 54.5
# Ship       - 53.9
# Truck      - 64.1
#
# Backdoor ASR 2.6
#
#  | Global training round : 5/100 |
#
# Average of peers' local losses: 1.070637
#
# Average test loss: 1.2624, Test accuracy: 5409/10000 (54.09%)
#
# Class      - Accuracy
# Plane      - 55.7
# Car        - 51.9
# Bird       - 36.2
# Cat        - 17.9
# Deer       - 51.7
# Dog        - 58.7
# Frog       - 73.2
# Horse      - 68.0
# Ship       - 60.7
# Truck      - 66.9
#
# Backdoor ASR 2.1
#
#  | Global training round : 6/100 |
#
# Average of peers' local losses: 0.923131
#
# Average test loss: 1.1508, Test accuracy: 5860/10000 (58.60%)
#
# Class      - Accuracy
# Plane      - 60.7
# Car        - 58.4
# Bird       - 32.8
# Cat        - 26.5
# Deer       - 62.5
# Dog        - 57.9
# Frog       - 80.4
# Horse      - 66.4
# Ship       - 71.0
# Truck      - 69.4
#
# Backdoor ASR 2.1
#
#  | Global training round : 7/100 |
#
# Average of peers' local losses: 0.803752
#
# Average test loss: 1.0693, Test accuracy: 6238/10000 (62.38%)
#
# Class      - Accuracy
# Plane      - 65.3
# Car        - 62.1
# Bird       - 37.8
# Cat        - 35.8
# Deer       - 65.8
# Dog        - 55.8
# Frog       - 78.8
# Horse      - 71.3
# Ship       - 79.0
# Truck      - 72.1
#
# Backdoor ASR 2.6
#
#  | Global training round : 8/100 |
#
# Average of peers' local losses: 0.717903
#
# Average test loss: 1.0443, Test accuracy: 6428/10000 (64.28%)
#
# Class      - Accuracy
# Plane      - 65.3
# Car        - 67.9
# Bird       - 40.1
# Cat        - 32.5
# Deer       - 69.6
# Dog        - 67.1
# Frog       - 78.9
# Horse      - 69.0
# Ship       - 78.7
# Truck      - 73.7
#
# Backdoor ASR 1.8
#
#  | Global training round : 9/100 |
#
# Average of peers' local losses: 0.634974
#
# Average test loss: 1.0304, Test accuracy: 6570/10000 (65.70%)
#
# Class      - Accuracy
# Plane      - 72.9
# Car        - 67.5
# Bird       - 41.9
# Cat        - 31.1
# Deer       - 70.0
# Dog        - 62.1
# Frog       - 84.1
# Horse      - 70.0
# Ship       - 78.5
# Truck      - 78.9
#
# Backdoor ASR 2.7
#
#  | Global training round : 10/100 |
#
# Average of peers' local losses: 0.577415
#
# Average test loss: 1.0355, Test accuracy: 6665/10000 (66.65%)
#
# Class      - Accuracy
# Plane      - 71.9
# Car        - 72.1
# Bird       - 41.7
# Cat        - 25.5
# Deer       - 71.0
# Dog        - 66.3
# Frog       - 86.1
# Horse      - 72.7
# Ship       - 80.7
# Truck      - 78.5
#
# Backdoor ASR 2.4
#
#  | Global training round : 11/100 |
#
# Average of peers' local losses: 0.525164
#
# Average test loss: 0.9969, Test accuracy: 6808/10000 (68.08%)
#
# Class      - Accuracy
# Plane      - 72.2
# Car        - 73.5
# Bird       - 42.9
# Cat        - 33.9
# Deer       - 71.9
# Dog        - 65.2
# Frog       - 84.0
# Horse      - 75.3
# Ship       - 82.4
# Truck      - 79.5
#
# Backdoor ASR 2.2
#
#  | Global training round : 12/100 |
#
# Average of peers' local losses: 0.488435
#
# Average test loss: 0.9899, Test accuracy: 6866/10000 (68.66%)
#
# Class      - Accuracy
# Plane      - 73.1
# Car        - 72.1
# Bird       - 47.9
# Cat        - 37.1
# Deer       - 72.5
# Dog        - 63.0
# Frog       - 86.4
# Horse      - 73.9
# Ship       - 81.2
# Truck      - 79.4
#
# Backdoor ASR 2.9
#
#  | Global training round : 13/100 |
#
# Average of peers' local losses: 0.451467
#
# Average test loss: 0.9882, Test accuracy: 6927/10000 (69.27%)
#
# Class      - Accuracy
# Plane      - 76.6
# Car        - 75.3
# Bird       - 44.0
# Cat        - 30.9
# Deer       - 76.2
# Dog        - 66.8
# Frog       - 85.2
# Horse      - 75.8
# Ship       - 82.0
# Truck      - 79.9
#
# Backdoor ASR 3.1
#
#  | Global training round : 14/100 |
#
# Average of peers' local losses: 0.417639
#
# Average test loss: 0.9696, Test accuracy: 7004/10000 (70.04%)
#
# Class      - Accuracy
# Plane      - 74.6
# Car        - 79.0
# Bird       - 47.4
# Cat        - 36.5
# Deer       - 74.7
# Dog        - 66.0
# Frog       - 86.5
# Horse      - 74.5
# Ship       - 83.1
# Truck      - 78.1
#
# Backdoor ASR 3.3
#
#  | Global training round : 15/100 |
#
# Average of peers' local losses: 0.395168
#
# Average test loss: 1.0034, Test accuracy: 6989/10000 (69.89%)
#
# Class      - Accuracy
# Plane      - 77.7
# Car        - 76.4
# Bird       - 45.0
# Cat        - 32.0
# Deer       - 75.1
# Dog        - 66.6
# Frog       - 89.2
# Horse      - 75.9
# Ship       - 82.5
# Truck      - 78.5
#
# Backdoor ASR 4.4
#
#  | Global training round : 16/100 |
#
# Average of peers' local losses: 0.372441
#
# Average test loss: 0.9663, Test accuracy: 7093/10000 (70.93%)
#
# Class      - Accuracy
# Plane      - 76.6
# Car        - 78.7
# Bird       - 49.2
# Cat        - 35.3
# Deer       - 74.9
# Dog        - 68.2
# Frog       - 86.2
# Horse      - 76.7
# Ship       - 84.1
# Truck      - 79.4
#
# Backdoor ASR 4.7
#
#  | Global training round : 17/100 |
#
# Average of peers' local losses: 0.348809
#
# Average test loss: 0.9579, Test accuracy: 7146/10000 (71.46%)
#
# Class      - Accuracy
# Plane      - 79.2
# Car        - 81.3
# Bird       - 51.2
# Cat        - 34.8
# Deer       - 77.3
# Dog        - 67.9
# Frog       - 85.0
# Horse      - 77.1
# Ship       - 83.0
# Truck      - 77.8
#
# Backdoor ASR 5.7
#
#  | Global training round : 18/100 |
#
# Average of peers' local losses: 0.334469
#
# Average test loss: 0.9557, Test accuracy: 7159/10000 (71.59%)
#
# Class      - Accuracy
# Plane      - 77.7
# Car        - 78.3
# Bird       - 51.3
# Cat        - 35.6
# Deer       - 74.2
# Dog        - 69.2
# Frog       - 86.8
# Horse      - 78.3
# Ship       - 84.5
# Truck      - 80.0
#
# Backdoor ASR 6.5
#
#  | Global training round : 19/100 |
#
# Average of peers' local losses: 0.317453
#
# Average test loss: 0.9506, Test accuracy: 7136/10000 (71.36%)
#
# Class      - Accuracy
# Plane      - 78.4
# Car        - 77.9
# Bird       - 48.2
# Cat        - 37.5
# Deer       - 75.4
# Dog        - 68.8
# Frog       - 85.9
# Horse      - 78.8
# Ship       - 82.1
# Truck      - 80.6
#
# Backdoor ASR 7.0
#
#  | Global training round : 20/100 |
#
# Average of peers' local losses: 0.295434
#
# Average test loss: 0.9591, Test accuracy: 7206/10000 (72.06%)
#
# Class      - Accuracy
# Plane      - 77.8
# Car        - 79.1
# Bird       - 50.3
# Cat        - 38.0
# Deer       - 76.7
# Dog        - 68.8
# Frog       - 88.0
# Horse      - 77.2
# Ship       - 85.1
# Truck      - 79.6
#
# Backdoor ASR 8.5
#
#  | Global training round : 21/100 |
#
# Average of peers' local losses: 0.289542
#
# Average test loss: 0.9328, Test accuracy: 7246/10000 (72.46%)
#
# Class      - Accuracy
# Plane      - 80.1
# Car        - 81.7
# Bird       - 52.2
# Cat        - 38.5
# Deer       - 76.6
# Dog        - 70.2
# Frog       - 86.4
# Horse      - 77.1
# Ship       - 83.6
# Truck      - 78.2
#
# Backdoor ASR 9.9
#
#  | Global training round : 22/100 |
#
# Average of peers' local losses: 0.274865
#
# Average test loss: 0.9431, Test accuracy: 7229/10000 (72.29%)
#
# Class      - Accuracy
# Plane      - 77.5
# Car        - 80.2
# Bird       - 50.8
# Cat        - 37.2
# Deer       - 77.1
# Dog        - 70.9
# Frog       - 86.7
# Horse      - 77.5
# Ship       - 84.0
# Truck      - 81.0
#
# Backdoor ASR 9.3
#
#  | Global training round : 23/100 |
#
# Average of peers' local losses: 0.264219
#
# Average test loss: 0.9345, Test accuracy: 7259/10000 (72.59%)
#
# Class      - Accuracy
# Plane      - 77.9
# Car        - 80.2
# Bird       - 53.1
# Cat        - 36.6
# Deer       - 76.0
# Dog        - 72.1
# Frog       - 85.8
# Horse      - 78.2
# Ship       - 85.0
# Truck      - 81.0
# Backdoor ASR 9.3
#
#  | Global training round : 24/100 |
#
# Average of peers' local losses: 0.254991
#
# Average test loss: 0.9213, Test accuracy: 7292/10000 (72.92%)
#
# Class      - Accuracy
# Plane      - 79.3
# Car        - 81.1
# Bird       - 53.1
# Cat        - 39.6
# Deer       - 78.3
# Dog        - 72.1
# Frog       - 85.2
# Horse      - 75.9
# Ship       - 84.6
# Truck      - 80.0
#
# Backdoor ASR 10.8
#
#  | Global training round : 25/100 |
#
# Average of peers' local losses: 0.242121
#
# Average test loss: 0.9287, Test accuracy: 7306/10000 (73.06%)
#
# Class      - Accuracy
# Plane      - 78.7
# Car        - 79.8
# Bird       - 56.2
# Cat        - 37.5
# Deer       - 78.1
# Dog        - 70.0
# Frog       - 85.3
# Horse      - 78.7
# Ship       - 85.9
# Truck      - 80.4
#
# Backdoor ASR 13.8
#
#  | Global training round : 26/100 |
#
# Average of peers' local losses: 0.236385
#
# Average test loss: 0.9373, Test accuracy: 7300/10000 (73.00%)
#
# Class      - Accuracy
# Plane      - 79.9
# Car        - 80.9
# Bird       - 53.9
# Cat        - 37.5
# Deer       - 77.2
# Dog        - 70.9
# Frog       - 87.5
# Horse      - 76.9
# Ship       - 84.4
# Truck      - 80.9
#
# Backdoor ASR 13.0
#
#  | Global training round : 27/100 |
#
# Average of peers' local losses: 0.224452
#
# Average test loss: 0.9200, Test accuracy: 7326/10000 (73.26%)
#
# Class      - Accuracy
# Plane      - 78.1
# Car        - 79.9
# Bird       - 55.3
# Cat        - 40.2
# Deer       - 77.1
# Dog        - 71.2
# Frog       - 86.2
# Horse      - 76.8
# Ship       - 86.1
# Truck      - 81.7
#
# Backdoor ASR 14.3
#
#  | Global training round : 28/100 |
#
# Average of peers' local losses: 0.217296
#
# Average test loss: 0.9318, Test accuracy: 7319/10000 (73.19%)
#
# Class      - Accuracy
# Plane      - 79.6
# Car        - 81.5
# Bird       - 53.5
# Cat        - 39.7
# Deer       - 76.8
# Dog        - 69.6
# Frog       - 88.5
# Horse      - 76.4
# Ship       - 84.4
# Truck      - 81.9
#
# Backdoor ASR 13.9
#
#  | Global training round : 29/100 |
#
# Average of peers' local losses: 0.210431
#
# Average test loss: 0.9144, Test accuracy: 7357/10000 (73.57%)
#
# Class      - Accuracy
# Plane      - 79.1
# Car        - 82.2
# Bird       - 55.2
# Cat        - 38.7
# Deer       - 77.0
# Dog        - 72.8
# Frog       - 86.0
# Horse      - 78.1
# Ship       - 86.1
# Truck      - 80.5
#
# Backdoor ASR 16.7
#
#  | Global training round : 30/100 |
#
# Average of peers' local losses: 0.203834
#
# Average test loss: 0.8962, Test accuracy: 7391/10000 (73.91%)
#
# Class      - Accuracy
# Plane      - 80.0
# Car        - 80.3
# Bird       - 55.7
# Cat        - 43.2
# Deer       - 77.7
# Dog        - 69.7
# Frog       - 87.1
# Horse      - 77.7
# Ship       - 85.3
# Truck      - 82.4
#
# Backdoor ASR 16.2
#
#  | Global training round : 31/100 |
#
# Average of peers' local losses: 0.197097
#
# Average test loss: 0.9191, Test accuracy: 7380/10000 (73.80%)
#
# Class      - Accuracy
# Plane      - 79.0
# Car        - 82.0
# Bird       - 55.0
# Cat        - 40.6
# Deer       - 77.7
# Dog        - 71.2
# Frog       - 88.3
# Horse      - 77.2
# Ship       - 85.4
# Truck      - 81.6
#
# Backdoor ASR 17.8
#
#  | Global training round : 32/100 |
#
# Average of peers' local losses: 0.193486
#
# Average test loss: 0.9133, Test accuracy: 7357/10000 (73.57%)
#
# Class      - Accuracy
# Plane      - 78.2
# Car        - 81.9
# Bird       - 54.3
# Cat        - 39.5
# Deer       - 78.0
# Dog        - 70.8
# Frog       - 87.2
# Horse      - 77.5
# Ship       - 86.9
# Truck      - 81.4
#
# Backdoor ASR 18.4
#
#  | Global training round : 33/100 |
#
# Average of peers' local losses: 0.183519
#
# Average test loss: 0.9020, Test accuracy: 7380/10000 (73.80%)
#
# Class      - Accuracy
# Plane      - 78.2
# Car        - 82.9
# Bird       - 54.7
# Cat        - 41.5
# Deer       - 78.4
# Dog        - 71.2
# Frog       - 87.2
# Horse      - 77.2
# Ship       - 86.2
# Truck      - 80.5
#
# Backdoor ASR 17.6
#
#  | Global training round : 34/100 |
#
# Average of peers' local losses: 0.174301
#
# Average test loss: 0.9020, Test accuracy: 7383/10000 (73.83%)
#
# Class      - Accuracy
# Plane      - 80.3
# Car        - 82.9
# Bird       - 54.7
# Cat        - 43.7
# Deer       - 76.8
# Dog        - 69.4
# Frog       - 87.6
# Horse      - 77.1
# Ship       - 84.3
# Truck      - 81.5
#
# Backdoor ASR 21.9
#
#  | Global training round : 35/100 |
#
# Average of peers' local losses: 0.171204
#
# Average test loss: 0.9166, Test accuracy: 7376/10000 (73.76%)
#
# Class      - Accuracy
# Plane      - 79.9
# Car        - 82.0
# Bird       - 55.0
# Cat        - 41.0
# Deer       - 75.0
# Dog        - 69.6
# Frog       - 89.6
# Horse      - 77.4
# Ship       - 86.7
# Truck      - 81.4
#
# Backdoor ASR 24.5
#
#  | Global training round : 36/100 |
#
# Average of peers' local losses: 0.164191
#
# Average test loss: 0.9052, Test accuracy: 7436/10000 (74.36%)
#
# Class      - Accuracy
# Plane      - 78.8
# Car        - 82.6
# Bird       - 57.5
# Cat        - 44.0
# Deer       - 76.9
# Dog        - 69.6
# Frog       - 87.5
# Horse      - 78.4
# Ship       - 87.9
# Truck      - 80.4
#
# Backdoor ASR 23.8
#
#  | Global training round : 37/100 |
#
# Average of peers' local losses: 0.162544
#
# Average test loss: 0.8974, Test accuracy: 7446/10000 (74.46%)
#
# Class      - Accuracy
# Plane      - 80.0
# Car        - 81.9
# Bird       - 57.7
# Cat        - 44.8
# Deer       - 78.8
# Dog        - 69.2
# Frog       - 86.6
# Horse      - 78.2
# Ship       - 85.1
# Truck      - 82.3
#
# Backdoor ASR 25.0
#
#  | Global training round : 38/100 |
#
# Average of peers' local losses: 0.151294
#
# Average test loss: 0.9121, Test accuracy: 7450/10000 (74.50%)
#
# Class      - Accuracy
# Plane      - 79.5
# Car        - 82.3
# Bird       - 57.9
# Cat        - 41.9
# Deer       - 79.0
# Dog        - 71.5
# Frog       - 87.4
# Horse      - 77.5
# Ship       - 85.6
# Truck      - 82.4
#
# Backdoor ASR 25.1
#
#  | Global training round : 39/100 |
#
# Average of peers' local losses: 0.151539
#
# Average test loss: 0.9140, Test accuracy: 7444/10000 (74.44%)
#
# Class      - Accuracy
# Plane      - 80.1
# Car        - 81.8
# Bird       - 56.3
# Cat        - 41.7
# Deer       - 76.0
# Dog        - 70.8
# Frog       - 90.0
# Horse      - 79.4
# Ship       - 87.1
# Truck      - 81.2
#
# Backdoor ASR 28.2
#
#  | Global training round : 40/100 |
#
# Average of peers' local losses: 0.143256
#
# Average test loss: 0.9074, Test accuracy: 7464/10000 (74.64%)
#
# Class      - Accuracy
# Plane      - 80.2
# Car        - 82.0
# Bird       - 55.9
# Cat        - 43.8
# Deer       - 76.6
# Dog        - 71.8
# Frog       - 88.7
# Horse      - 80.7
# Ship       - 86.4
# Truck      - 80.3
#
# Backdoor ASR 29.4
#
#  | Global training round : 41/100 |
#
# Average of peers' local losses: 0.136245
#
# Average test loss: 0.9074, Test accuracy: 7451/10000 (74.51%)
#
# Class      - Accuracy
# Plane      - 80.0
# Car        - 83.6
# Bird       - 57.0
# Cat        - 43.4
# Deer       - 77.5
# Dog        - 69.6
# Frog       - 88.2
# Horse      - 78.4
# Ship       - 86.3
# Truck      - 81.1
#
# Backdoor ASR 29.0
#
#  | Global training round : 42/100 |
#
# Average of peers' local losses: 0.132941
#
# Average test loss: 0.9036, Test accuracy: 7496/10000 (74.96%)
#
# Class      - Accuracy
# Plane      - 79.0
# Car        - 82.6
# Bird       - 59.4
# Cat        - 44.6
# Deer       - 79.3
# Dog        - 69.3
# Frog       - 87.2
# Horse      - 78.7
# Ship       - 87.6
# Truck      - 81.9
#
# Backdoor ASR 30.7
#
#  | Global training round : 43/100 |
#
# Average of peers' local losses: 0.127543
#
# Average test loss: 0.9128, Test accuracy: 7474/10000 (74.74%)
#
# Class      - Accuracy
# Plane      - 79.3
# Car        - 83.3
# Bird       - 55.3
# Cat        - 42.1
# Deer       - 79.3
# Dog        - 73.2
# Frog       - 86.7
# Horse      - 80.1
# Ship       - 87.4
# Truck      - 80.7
#
# Backdoor ASR 31.8
#
#  | Global training round : 44/100 |
#
# Average of peers' local losses: 0.123243
#
# Average test loss: 0.9119, Test accuracy: 7466/10000 (74.66%)
#
# Class      - Accuracy
# Plane      - 81.1
# Car        - 83.6
# Bird       - 56.6
# Cat        - 43.7
# Deer       - 77.8
# Dog        - 71.9
# Frog       - 87.2
# Horse      - 78.5
# Ship       - 86.2
# Truck      - 80.0
#
# Backdoor ASR 32.8
#
#  | Global training round : 45/100 |
#
# Average of peers' local losses: 0.116793
#
# Average test loss: 0.9069, Test accuracy: 7505/10000 (75.05%)
#
# Class      - Accuracy
# Plane      - 80.2
# Car        - 83.0
# Bird       - 59.2
# Cat        - 44.5
# Deer       - 77.8
# Dog        - 69.4
# Frog       - 87.8
# Horse      - 80.0
# Ship       - 87.6
# Truck      - 81.0
#
# Backdoor ASR 33.8
#
#  | Global training round : 46/100 |
#
# Average of peers' local losses: 0.118488
#
# Average test loss: 0.9104, Test accuracy: 7491/10000 (74.91%)
#
# Class      - Accuracy
# Plane      - 80.3
# Car        - 82.8
# Bird       - 60.7
# Cat        - 40.7
# Deer       - 77.8
# Dog        - 70.2
# Frog       - 87.8
# Horse      - 79.9
# Ship       - 86.5
# Truck      - 82.4
# Backdoor ASR 31.6
#
#  | Global training round : 47/100 |
#
# Average of peers' local losses: 0.103871
#
# Average test loss: 0.9096, Test accuracy: 7516/10000 (75.16%)
#
# Class      - Accuracy
# Plane      - 81.6
# Car        - 84.8
# Bird       - 58.8
# Cat        - 42.7
# Deer       - 77.2
# Dog        - 71.3
# Frog       - 87.7
# Horse      - 81.0
# Ship       - 87.1
# Truck      - 79.4
#
# Backdoor ASR 37.6
#
#  | Global training round : 48/100 |
#
# Average of peers' local losses: 0.100582
#
# Average test loss: 0.9245, Test accuracy: 7509/10000 (75.09%)
#
# Class      - Accuracy
# Plane      - 80.6
# Car        - 84.3
# Bird       - 61.6
# Cat        - 42.3
# Deer       - 76.4
# Dog        - 71.4
# Frog       - 86.6
# Horse      - 81.2
# Ship       - 86.0
# Truck      - 80.5
#
# Backdoor ASR 37.9
#
#  | Global training round : 49/100 |
#
# Average of peers' local losses: 0.112641
#
# Average test loss: 0.9069, Test accuracy: 7483/10000 (74.83%)
#
# Class      - Accuracy
# Plane      - 80.7
# Car        - 82.3
# Bird       - 59.6
# Cat        - 45.2
# Deer       - 78.8
# Dog        - 70.7
# Frog       - 87.8
# Horse      - 76.4
# Ship       - 85.9
# Truck      - 80.9
#
# Backdoor ASR 36.4
#
#  | Global training round : 50/100 |
#
# Average of peers' local losses: 0.088262
#
# Average test loss: 0.9451, Test accuracy: 7506/10000 (75.06%)
#
# Class      - Accuracy
# Plane      - 81.5
# Car        - 82.3
# Bird       - 59.1
# Cat        - 42.5
# Deer       - 77.2
# Dog        - 71.0
# Frog       - 86.5
# Horse      - 81.5
# Ship       - 86.8
# Truck      - 82.2
#
# Backdoor ASR 39.8
#
#  | Global training round : 51/100 |
#
# Average of peers' local losses: 0.098313
#
# Average test loss: 0.9349, Test accuracy: 7493/10000 (74.93%)
#
# Class      - Accuracy
# Plane      - 80.7
# Car        - 84.4
# Bird       - 57.5
# Cat        - 40.4
# Deer       - 77.8
# Dog        - 71.3
# Frog       - 87.1
# Horse      - 82.4
# Ship       - 86.1
# Truck      - 81.6
#
# Backdoor ASR 36.4
#
#  | Global training round : 52/100 |
#
# Average of peers' local losses: 0.096399
#
# Average test loss: 0.9151, Test accuracy: 7515/10000 (75.15%)
#
# Class      - Accuracy
# Plane      - 81.5
# Car        - 84.2
# Bird       - 62.0
# Cat        - 42.3
# Deer       - 76.7
# Dog        - 72.0
# Frog       - 87.3
# Horse      - 79.7
# Ship       - 84.9
# Truck      - 80.9
#
# Backdoor ASR 39.7
#
#  | Global training round : 53/100 |
#
# Average of peers' local losses: 0.089970
#
# Average test loss: 0.9369, Test accuracy: 7520/10000 (75.20%)
#
# Class      - Accuracy
# Plane      - 80.2
# Car        - 85.0
# Bird       - 60.4
# Cat        - 43.0
# Deer       - 77.0
# Dog        - 72.9
# Frog       - 87.9
# Horse      - 79.1
# Ship       - 85.3
# Truck      - 81.2
#
# Backdoor ASR 40.2
#
#  | Global training round : 54/100 |
#
# Average of peers' local losses: 0.098477
#
# Average test loss: 0.9056, Test accuracy: 7510/10000 (75.10%)
#
# Class      - Accuracy
# Plane      - 81.0
# Car        - 83.2
# Bird       - 60.6
# Cat        - 44.9
# Deer       - 76.2
# Dog        - 70.8
# Frog       - 87.9
# Horse      - 79.3
# Ship       - 86.1
# Truck      - 81.0
#
# Backdoor ASR 43.8
#
#  | Global training round : 55/100 |
#
# Average of peers' local losses: 0.084045
#
# Average test loss: 0.9212, Test accuracy: 7515/10000 (75.15%)
#
# Class      - Accuracy
# Plane      - 80.6
# Car        - 82.6
# Bird       - 59.0
# Cat        - 43.8
# Deer       - 78.0
# Dog        - 72.7
# Frog       - 86.5
# Horse      - 80.0
# Ship       - 86.3
# Truck      - 82.0
#
# Backdoor ASR 45.4
#
#  | Global training round : 56/100 |
#
# Average of peers' local losses: 0.083555
#
# Average test loss: 0.9306, Test accuracy: 7515/10000 (75.15%)
#
# Class      - Accuracy
# Plane      - 80.9
# Car        - 84.0
# Bird       - 60.5
# Cat        - 44.8
# Deer       - 75.7
# Dog        - 70.0
# Frog       - 86.5
# Horse      - 81.5
# Ship       - 86.3
# Truck      - 81.3
#
# Backdoor ASR 44.4
#
#  | Global training round : 57/100 |
#
# Average of peers' local losses: 0.092637
#
# Average test loss: 0.9233, Test accuracy: 7532/10000 (75.32%)
#
# Class      - Accuracy
# Plane      - 81.5
# Car        - 83.4
# Bird       - 60.6
# Cat        - 42.9
# Deer       - 78.6
# Dog        - 70.2
# Frog       - 88.9
# Horse      - 80.2
# Ship       - 85.3
# Truck      - 81.6
#
# Backdoor ASR 43.1
#
#  | Global training round : 58/100 |
#
# Average of peers' local losses: 0.091181
#
# Average test loss: 0.9250, Test accuracy: 7507/10000 (75.07%)
#
# Class      - Accuracy
# Plane      - 80.7
# Car        - 82.8
# Bird       - 58.2
# Cat        - 44.5
# Deer       - 76.9
# Dog        - 70.8
# Frog       - 87.7
# Horse      - 80.7
# Ship       - 86.3
# Truck      - 82.1
#
# Backdoor ASR 46.9
#
#  | Global training round : 59/100 |
#
# Average of peers' local losses: 0.064871
#
# Average test loss: 0.9608, Test accuracy: 7510/10000 (75.10%)
#
# Class      - Accuracy
# Plane      - 80.8
# Car        - 83.4
# Bird       - 61.2
# Cat        - 42.6
# Deer       - 77.5
# Dog        - 70.6
# Frog       - 86.0
# Horse      - 81.0
# Ship       - 85.3
# Truck      - 82.6
#
# Backdoor ASR 48.2
#
#  | Global training round : 60/100 |
#
# Average of peers' local losses: 0.099130
#
# Average test loss: 0.8947, Test accuracy: 7529/10000 (75.29%)
#
# Class      - Accuracy
# Plane      - 80.7
# Car        - 82.5
# Bird       - 59.5
# Cat        - 45.1
# Deer       - 75.4
# Dog        - 71.2
# Frog       - 88.6
# Horse      - 82.1
# Ship       - 85.9
# Truck      - 81.9
#
# Backdoor ASR 43.5
#
#  | Global training round : 61/100 |
#
# Average of peers' local losses: 0.060870
#
# Average test loss: 0.9421, Test accuracy: 7535/10000 (75.35%)
#
# Class      - Accuracy
# Plane      - 79.4
# Car        - 85.2
# Bird       - 61.1
# Cat        - 46.0
# Deer       - 77.4
# Dog        - 71.0
# Frog       - 84.9
# Horse      - 80.4
# Ship       - 86.7
# Truck      - 81.4
#
# Backdoor ASR 48.7
#
#  | Global training round : 62/100 |
#
# Average of peers' local losses: 0.087557
#
# Average test loss: 0.9147, Test accuracy: 7508/10000 (75.08%)
#
# Class      - Accuracy
# Plane      - 80.8
# Car        - 82.8
# Bird       - 57.5
# Cat        - 45.3
# Deer       - 77.4
# Dog        - 70.0
# Frog       - 88.7
# Horse      - 82.0
# Ship       - 86.4
# Truck      - 79.9
#
# Backdoor ASR 45.7
#
#  | Global training round : 63/100 |
#
# Average of peers' local losses: 0.076913
#
# Average test loss: 0.9214, Test accuracy: 7529/10000 (75.29%)
#
# Class      - Accuracy
# Plane      - 82.5
# Car        - 83.0
# Bird       - 61.8
# Cat        - 44.4
# Deer       - 75.4
# Dog        - 69.3
# Frog       - 87.8
# Horse      - 80.4
# Ship       - 86.3
# Truck      - 82.0
#
# Backdoor ASR 47.9
#
#  | Global training round : 64/100 |
#
# Average of peers' local losses: 0.078700
#
# Average test loss: 0.9306, Test accuracy: 7530/10000 (75.30%)
#
# Class      - Accuracy
# Plane      - 81.4
# Car        - 81.3
# Bird       - 60.6
# Cat        - 43.2
# Deer       - 78.4
# Dog        - 71.1
# Frog       - 86.7
# Horse      - 81.5
# Ship       - 85.9
# Truck      - 82.9
#
# Backdoor ASR 48.7
#
#  | Global training round : 65/100 |
#
# Average of peers' local losses: 0.077727
#
# Average test loss: 0.9347, Test accuracy: 7504/10000 (75.04%)
#
# Class      - Accuracy
# Plane      - 81.6
# Car        - 84.8
# Bird       - 60.6
# Cat        - 41.7
# Deer       - 78.0
# Dog        - 70.7
# Frog       - 88.1
# Horse      - 79.0
# Ship       - 84.1
# Truck      - 81.8
#
# Backdoor ASR 49.7
#
#  | Global training round : 66/100 |
#
# Average of peers' local losses: 0.086843
#
# Average test loss: 0.8919, Test accuracy: 7502/10000 (75.02%)
#
# Class      - Accuracy
# Plane      - 79.7
# Car        - 84.7
# Bird       - 60.2
# Cat        - 43.8
# Deer       - 75.7
# Dog        - 71.3
# Frog       - 88.3
# Horse      - 80.1
# Ship       - 86.5
# Truck      - 79.9
#
# Backdoor ASR 46.0
#
#  | Global training round : 67/100 |
#
# Average of peers' local losses: 0.054153
#
# Average test loss: 0.9468, Test accuracy: 7531/10000 (75.31%)
#
# Class      - Accuracy
# Plane      - 81.1
# Car        - 84.2
# Bird       - 60.0
# Cat        - 47.7
# Deer       - 76.5
# Dog        - 69.7
# Frog       - 86.4
# Horse      - 81.2
# Ship       - 84.8
# Truck      - 81.5
#
# Backdoor ASR 50.9
#
#  | Global training round : 68/100 |
#
# Average of peers' local losses: 0.089614
#
# Average test loss: 0.9105, Test accuracy: 7520/10000 (75.20%)
#
# Class      - Accuracy
# Plane      - 80.7
# Car        - 85.3
# Bird       - 58.9
# Cat        - 43.0
# Deer       - 76.8
# Dog        - 68.6
# Frog       - 89.1
# Horse      - 82.0
# Ship       - 86.5
# Truck      - 81.1
#
# Backdoor ASR 47.8
#
#  | Global training round : 69/100 |
#
# Average of peers' local losses: 0.066695
#
# Average test loss: 0.9463, Test accuracy: 7514/10000 (75.14%)
#
# Class      - Accuracy
# Plane      - 82.0
# Car        - 86.0
# Bird       - 60.5
# Cat        - 42.1
# Deer       - 78.0
# Dog        - 71.9
# Frog       - 87.5
# Horse      - 78.6
# Ship       - 84.7
# Truck      - 80.1
# Backdoor ASR 47.8
#
#  | Global training round : 70/100 |
#
# Average of peers' local losses: 0.088224
#
# Average test loss: 0.9005, Test accuracy: 7504/10000 (75.04%)
#
# Class      - Accuracy
# Plane      - 81.3
# Car        - 84.6
# Bird       - 58.2
# Cat        - 43.2
# Deer       - 77.8
# Dog        - 71.5
# Frog       - 87.7
# Horse      - 78.1
# Ship       - 86.7
# Truck      - 81.3
#
# Backdoor ASR 45.9
#
#  | Global training round : 71/100 |
#
# Average of peers' local losses: 0.078537
#
# Average test loss: 0.9105, Test accuracy: 7541/10000 (75.41%)
#
# Class      - Accuracy
# Plane      - 81.3
# Car        - 83.1
# Bird       - 60.5
# Cat        - 47.0
# Deer       - 78.2
# Dog        - 70.3
# Frog       - 87.1
# Horse      - 78.9
# Ship       - 87.8
# Truck      - 79.9
#
# Backdoor ASR 54.4
#
#  | Global training round : 72/100 |
#
# Average of peers' local losses: 0.074911
#
# Average test loss: 0.8985, Test accuracy: 7534/10000 (75.34%)
#
# Class      - Accuracy
# Plane      - 80.5
# Car        - 83.9
# Bird       - 61.9
# Cat        - 42.5
# Deer       - 76.4
# Dog        - 72.3
# Frog       - 88.0
# Horse      - 79.8
# Ship       - 85.8
# Truck      - 82.3
#
# Backdoor ASR 55.6
#
#  | Global training round : 73/100 |
#
# Average of peers' local losses: 0.074177
#
# Average test loss: 0.9017, Test accuracy: 7541/10000 (75.41%)
#
# Class      - Accuracy
# Plane      - 80.3
# Car        - 84.6
# Bird       - 60.0
# Cat        - 46.9
# Deer       - 74.9
# Dog        - 70.7
# Frog       - 88.6
# Horse      - 79.2
# Ship       - 87.5
# Truck      - 81.4
#
# Backdoor ASR 51.5
#
#  | Global training round : 74/100 |
#
# Average of peers' local losses: 0.069393
#
# Average test loss: 0.9244, Test accuracy: 7553/10000 (75.53%)
#
# Class      - Accuracy
# Plane      - 82.2
# Car        - 84.9
# Bird       - 61.4
# Cat        - 42.6
# Deer       - 77.3
# Dog        - 70.2
# Frog       - 87.8
# Horse      - 80.5
# Ship       - 87.1
# Truck      - 81.3
#
# Backdoor ASR 53.9
#
#  | Global training round : 75/100 |
#
# Average of peers' local losses: 0.073789
#
# Average test loss: 0.9153, Test accuracy: 7522/10000 (75.22%)
#
# Class      - Accuracy
# Plane      - 82.1
# Car        - 83.8
# Bird       - 57.9
# Cat        - 43.9
# Deer       - 78.4
# Dog        - 71.6
# Frog       - 88.1
# Horse      - 80.3
# Ship       - 85.6
# Truck      - 80.5
#
# Backdoor ASR 52.0
#
#  | Global training round : 76/100 |
#
# Average of peers' local losses: 0.079529
#
# Average test loss: 0.9218, Test accuracy: 7508/10000 (75.08%)
#
# Class      - Accuracy
# Plane      - 81.7
# Car        - 83.6
# Bird       - 60.1
# Cat        - 41.4
# Deer       - 77.9
# Dog        - 73.1
# Frog       - 88.1
# Horse      - 78.2
# Ship       - 86.6
# Truck      - 80.1
#
# Backdoor ASR 55.3
#
#  | Global training round : 77/100 |
#
# Average of peers' local losses: 0.077769
#
# Average test loss: 0.9124, Test accuracy: 7531/10000 (75.31%)
#
# Class      - Accuracy
# Plane      - 82.2
# Car        - 84.2
# Bird       - 61.7
# Cat        - 43.9
# Deer       - 76.7
# Dog        - 71.6
# Frog       - 88.0
# Horse      - 80.0
# Ship       - 85.7
# Truck      - 79.1
#
# Backdoor ASR 55.4
#
#  | Global training round : 78/100 |
#
# Average of peers' local losses: 0.071657
#
# Average test loss: 0.8930, Test accuracy: 7557/10000 (75.57%)
#
# Class      - Accuracy
# Plane      - 81.9
# Car        - 84.1
# Bird       - 60.3
# Cat        - 46.6
# Deer       - 77.7
# Dog        - 69.7
# Frog       - 87.1
# Horse      - 82.0
# Ship       - 85.3
# Truck      - 81.0
#
# Backdoor ASR 56.0
#
#  | Global training round : 79/100 |
#
# Average of peers' local losses: 0.083940
#
# Average test loss: 0.8933, Test accuracy: 7503/10000 (75.03%)
#
# Class      - Accuracy
# Plane      - 82.4
# Car        - 85.0
# Bird       - 58.5
# Cat        - 43.3
# Deer       - 78.4
# Dog        - 68.7
# Frog       - 87.4
# Horse      - 80.2
# Ship       - 85.1
# Truck      - 81.3
#
# Backdoor ASR 49.1
#
#  | Global training round : 80/100 |
#
# Average of peers' local losses: 0.069820
#
# Average test loss: 0.8963, Test accuracy: 7550/10000 (75.50%)
#
# Class      - Accuracy
# Plane      - 81.4
# Car        - 83.1
# Bird       - 62.4
# Cat        - 44.9
# Deer       - 78.8
# Dog        - 69.2
# Frog       - 88.0
# Horse      - 80.6
# Ship       - 84.5
# Truck      - 82.1
#
# Backdoor ASR 54.9
#
#  | Global training round : 81/100 |
#
# Average of peers' local losses: 0.079698
#
# Average test loss: 0.8969, Test accuracy: 7563/10000 (75.63%)
#
# Class      - Accuracy
# Plane      - 82.2
# Car        - 84.4
# Bird       - 63.9
# Cat        - 44.6
# Deer       - 75.3
# Dog        - 71.8
# Frog       - 87.5
# Horse      - 79.6
# Ship       - 86.1
# Truck      - 80.9
#
# Backdoor ASR 56.7
#
#  | Global training round : 82/100 |
#
# Average of peers' local losses: 0.094846
#
# Average test loss: 0.9040, Test accuracy: 7532/10000 (75.32%)
#
# Class      - Accuracy
# Plane      - 82.3
# Car        - 84.5
# Bird       - 59.2
# Cat        - 42.1
# Deer       - 76.5
# Dog        - 71.7
# Frog       - 88.8
# Horse      - 78.2
# Ship       - 87.6
# Truck      - 82.3
#
# Backdoor ASR 52.4
#
#  | Global training round : 83/100 |
#
# Average of peers' local losses: 0.062723
#
# Average test loss: 0.9169, Test accuracy: 7557/10000 (75.57%)
#
# Class      - Accuracy
# Plane      - 81.7
# Car        - 83.8
# Bird       - 61.8
# Cat        - 45.2
# Deer       - 75.7
# Dog        - 70.9
# Frog       - 87.6
# Horse      - 81.9
# Ship       - 85.9
# Truck      - 81.2
#
# Backdoor ASR 58.1
#
#  | Global training round : 84/100 |
#
# Average of peers' local losses: 0.086523
#
# Average test loss: 0.8696, Test accuracy: 7565/10000 (75.65%)
#
# Class      - Accuracy
# Plane      - 81.5
# Car        - 82.8
# Bird       - 62.7
# Cat        - 47.3
# Deer       - 77.6
# Dog        - 68.5
# Frog       - 87.8
# Horse      - 79.0
# Ship       - 87.3
# Truck      - 82.0
#
# Backdoor ASR 56.3
#
#  | Global training round : 85/100 |
#
# Average of peers' local losses: 0.097879
#
# Average test loss: 0.8575, Test accuracy: 7526/10000 (75.26%)
#
# Class      - Accuracy
# Plane      - 81.0
# Car        - 86.1
# Bird       - 58.4
# Cat        - 40.9
# Deer       - 78.0
# Dog        - 73.0
# Frog       - 88.3
# Horse      - 80.1
# Ship       - 86.1
# Truck      - 80.7
#
# Backdoor ASR 51.0
#
#  | Global training round : 86/100 |
#
# Average of peers' local losses: 0.064068
#
# Average test loss: 0.9193, Test accuracy: 7550/10000 (75.50%)
#
# Class      - Accuracy
# Plane      - 80.1
# Car        - 83.5
# Bird       - 59.8
# Cat        - 43.1
# Deer       - 78.9
# Dog        - 72.7
# Frog       - 87.5
# Horse      - 80.1
# Ship       - 87.1
# Truck      - 82.2
#
# Backdoor ASR 55.6
#
#  | Global training round : 87/100 |
#
# Average of peers' local losses: 0.073640
#
# Average test loss: 0.8932, Test accuracy: 7560/10000 (75.60%)
#
# Class      - Accuracy
# Plane      - 82.8
# Car        - 86.0
# Bird       - 62.8
# Cat        - 45.9
# Deer       - 76.1
# Dog        - 69.9
# Frog       - 86.4
# Horse      - 81.3
# Ship       - 85.6
# Truck      - 79.2
#
# Backdoor ASR 54.6
#
#  | Global training round : 88/100 |
#
# Average of peers' local losses: 0.085078
#
# Average test loss: 0.8785, Test accuracy: 7527/10000 (75.27%)
#
# Class      - Accuracy
# Plane      - 80.7
# Car        - 83.7
# Bird       - 61.3
# Cat        - 44.7
# Deer       - 76.7
# Dog        - 69.8
# Frog       - 87.3
# Horse      - 79.6
# Ship       - 87.2
# Truck      - 81.7
#
# Backdoor ASR 53.5
#
#  | Global training round : 89/100 |
#
# Average of peers' local losses: 0.077279
#
# Average test loss: 0.8843, Test accuracy: 7543/10000 (75.43%)
#
# Class      - Accuracy
# Plane      - 80.9
# Car        - 84.3
# Bird       - 59.8
# Cat        - 44.9
# Deer       - 78.9
# Dog        - 70.7
# Frog       - 88.2
# Horse      - 79.3
# Ship       - 86.0
# Truck      - 81.3
#
# Backdoor ASR 51.7
#
#  | Global training round : 90/100 |
#
# Average of peers' local losses: 0.047174
#
# Average test loss: 0.9613, Test accuracy: 7535/10000 (75.35%)
#
# Class      - Accuracy
# Plane      - 80.8
# Car        - 84.6
# Bird       - 61.5
# Cat        - 47.3
# Deer       - 74.7
# Dog        - 69.6
# Frog       - 87.4
# Horse      - 80.7
# Ship       - 86.6
# Truck      - 80.3
#
# Backdoor ASR 60.1
#
#  | Global training round : 91/100 |
#
# Average of peers' local losses: 0.103184
#
# Average test loss: 0.8743, Test accuracy: 7519/10000 (75.19%)
#
# Class      - Accuracy
# Plane      - 81.4
# Car        - 84.5
# Bird       - 59.1
# Cat        - 41.4
# Deer       - 77.2
# Dog        - 72.2
# Frog       - 86.9
# Horse      - 79.7
# Ship       - 87.4
# Truck      - 82.1
#
# Backdoor ASR 53.8
#
#  | Global training round : 92/100 |
#
# Average of peers' local losses: 0.082154
#
# Average test loss: 0.8827, Test accuracy: 7539/10000 (75.39%)
#
# Class      - Accuracy
# Plane      - 82.7
# Car        - 82.7
# Bird       - 61.0
# Cat        - 42.2
# Deer       - 76.3
# Dog        - 72.7
# Frog       - 87.9
# Horse      - 80.4
# Ship       - 86.4
# Truck      - 81.6
# Backdoor ASR 52.2
#
#  | Global training round : 93/100 |
#
# Average of peers' local losses: 0.094312
#
# Average test loss: 0.8665, Test accuracy: 7553/10000 (75.53%)
#
# Class      - Accuracy
# Plane      - 81.6
# Car        - 84.4
# Bird       - 61.4
# Cat        - 43.7
# Deer       - 77.5
# Dog        - 70.5
# Frog       - 88.8
# Horse      - 80.6
# Ship       - 87.1
# Truck      - 79.7
#
# Backdoor ASR 53.1
#
#  | Global training round : 94/100 |
#
# Average of peers' local losses: 0.067481
#
# Average test loss: 0.9177, Test accuracy: 7559/10000 (75.59%)
#
# Class      - Accuracy
# Plane      - 81.6
# Car        - 84.6
# Bird       - 63.1
# Cat        - 43.4
# Deer       - 75.4
# Dog        - 71.2
# Frog       - 87.4
# Horse      - 80.5
# Ship       - 85.9
# Truck      - 82.8
#
# Backdoor ASR 61.4
#
#  | Global training round : 95/100 |
#
# Average of peers' local losses: 0.085488
#
# Average test loss: 0.8680, Test accuracy: 7567/10000 (75.67%)
#
# Class      - Accuracy
# Plane      - 82.7
# Car        - 83.7
# Bird       - 61.1
# Cat        - 46.0
# Deer       - 76.5
# Dog        - 70.1
# Frog       - 87.4
# Horse      - 80.0
# Ship       - 86.1
# Truck      - 83.1
#
# Backdoor ASR 59.2
#
#  | Global training round : 96/100 |
#
# Average of peers' local losses: 0.081998
#
# Average test loss: 0.8767, Test accuracy: 7570/10000 (75.70%)
#
# Class      - Accuracy
# Plane      - 80.9
# Car        - 83.1
# Bird       - 60.3
# Cat        - 47.5
# Deer       - 78.1
# Dog        - 70.2
# Frog       - 87.2
# Horse      - 80.6
# Ship       - 86.2
# Truck      - 82.9
#
# Backdoor ASR 58.3
#
#  | Global training round : 97/100 |
#
# Average of peers' local losses: 0.070026
#
# Average test loss: 0.8752, Test accuracy: 7522/10000 (75.22%)
#
# Class      - Accuracy
# Plane      - 81.5
# Car        - 83.1
# Bird       - 58.9
# Cat        - 41.3
# Deer       - 76.5
# Dog        - 73.4
# Frog       - 86.8
# Horse      - 81.2
# Ship       - 86.8
# Truck      - 82.7
#
# Backdoor ASR 57.0
#
#  | Global training round : 98/100 |
#
# Average of peers' local losses: 0.096374
#
# Average test loss: 0.8460, Test accuracy: 7558/10000 (75.58%)
#
# Class      - Accuracy
# Plane      - 80.0
# Car        - 84.3
# Bird       - 62.2
# Cat        - 44.2
# Deer       - 76.7
# Dog        - 69.6
# Frog       - 87.6
# Horse      - 80.9
# Ship       - 87.2
# Truck      - 83.1
#
# Backdoor ASR 56.2
#
#  | Global training round : 99/100 |
#
# Average of peers' local losses: 0.078466
#
# Average test loss: 0.8622, Test accuracy: 7572/10000 (75.72%)
#
# Class      - Accuracy
# Plane      - 81.2
# Car        - 83.1
# Bird       - 62.8
# Cat        - 46.4
# Deer       - 77.3
# Dog        - 72.2
# Frog       - 86.6
# Horse      - 78.7
# Ship       - 86.5
# Truck      - 82.4
#
# Backdoor ASR 60.7
#
#  | Global training round : 100/100 |
#
# Average of peers' local losses: 0.085676
#
# Average test loss: 0.8584, Test accuracy: 7564/10000 (75.64%)
#
# Class      - Accuracy
# Plane      - 82.3
# Car        - 84.8
# Bird       - 62.2
# Cat        - 44.0
# Deer       - 77.6
# Dog        - 69.0
# Frog       - 87.7
# Horse      - 79.9
# Ship       - 88.0
# Truck      - 80.9
#
# Backdoor ASR 56.8
# Last 10 updates results
#
# Average test loss: 0.8588, Test accuracy: 7573/10000 (75.73%)
#
# ***********************************************************************************
# Class      - Accuracy
# Plane      - 81.8
# Car        - 84.0
# Bird       - 61.5
# Cat        - 44.2
# Deer       - 77.3
# Dog        - 71.3
# Frog       - 88.0
# Horse      - 80.1
# Ship       - 87.0
# Truck      - 82.1
# Global accuracies:  [10.0, 10.7, 32.32, 47.72, 54.09, 58.6, 62.38, 64.28, 65.7, 66.65, 68.08, 68.66, 69.27, 70.04, 69.89, 70.93, 71.46, 71.59, 71.36, 72.06, 72.46, 72.29, 72.59, 72.92, 73.06, 73.0, 73.26, 73.19, 73.57, 73.91, 73.8, 73.57, 73.8, 73.83, 73.76, 74.36, 74.46, 74.5, 74.44, 74.64, 74.51, 74.96, 74.74, 74.66, 75.05, 74.91, 75.16, 75.09, 74.83, 75.06, 74.93, 75.15, 75.2, 75.1, 75.15, 75.15, 75.32, 75.07, 75.1, 75.29, 75.35, 75.08, 75.29, 75.3, 75.04, 75.02, 75.31, 75.2, 75.14, 75.04, 75.41, 75.34, 75.41, 75.53, 75.22, 75.08, 75.31, 75.57, 75.03, 75.5, 75.63, 75.32, 75.57, 75.65, 75.26, 75.5, 75.6, 75.27, 75.43, 75.35, 75.19, 75.39, 75.53, 75.59, 75.67, 75.7, 75.22, 75.58, 75.72, 75.64, 75.73]
# Class 1 accuracies:  [0.0, 0.0, 5.6, 38.6, 51.9, 58.4, 62.1, 67.9, 67.5, 72.1, 73.5, 72.1, 75.3, 79.0, 76.4, 78.7, 81.3, 78.3, 77.9, 79.1, 81.7, 80.2, 80.2, 81.1, 79.8, 80.9, 79.9, 81.5, 82.2, 80.3, 82.0, 81.9, 82.9, 82.9, 82.0, 82.6, 81.9, 82.3, 81.8, 82.0, 83.6, 82.6, 83.3, 83.6, 83.0, 82.8, 84.8, 84.3, 82.3, 82.3, 84.4, 84.2, 85.0, 83.2, 82.6, 84.0, 83.4, 82.8, 83.4, 82.5, 85.2, 82.8, 83.0, 81.3, 84.8, 84.7, 84.2, 85.3, 86.0, 84.6, 83.1, 83.9, 84.6, 84.9, 83.8, 83.6, 84.2, 84.1, 85.0, 83.1, 84.4, 84.5, 83.8, 82.8, 86.1, 83.5, 86.0, 83.7, 84.3, 84.6, 84.5, 82.7, 84.4, 84.6, 83.7, 83.1, 83.1, 84.3, 83.1, 84.8, 84.0]
# Test loss: [2.3447, 2.2772, 1.9148, 1.4609, 1.2624, 1.1508, 1.0693, 1.0443, 1.0304, 1.0355, 0.9969, 0.9899, 0.9882, 0.9696, 1.0034, 0.9663, 0.9579, 0.9557, 0.9506, 0.9591, 0.9328, 0.9431, 0.9345, 0.9213, 0.9287, 0.9373, 0.92, 0.9318, 0.9144, 0.8962, 0.9191, 0.9133, 0.902, 0.902, 0.9166, 0.9052, 0.8974, 0.9121, 0.914, 0.9074, 0.9074, 0.9036, 0.9128, 0.9119, 0.9069, 0.9104, 0.9096, 0.9245, 0.9069, 0.9451, 0.9349, 0.9151, 0.9369, 0.9056, 0.9212, 0.9306, 0.9233, 0.925, 0.9608, 0.8947, 0.9421, 0.9147, 0.9214, 0.9306, 0.9347, 0.8919, 0.9468, 0.9105, 0.9463, 0.9005, 0.9105, 0.8985, 0.9017, 0.9244, 0.9153, 0.9218, 0.9124, 0.893, 0.8933, 0.8963, 0.8969, 0.904, 0.9169, 0.8696, 0.8575, 0.9193, 0.8932, 0.8785, 0.8843, 0.9613, 0.8743, 0.8827, 0.8665, 0.9177, 0.868, 0.8767, 0.8752, 0.846, 0.8622, 0.8584, 0.8588]
# Label-flipping attack succes rate: 0.5
# Backdoor attack succes rate: 57.1
# Average CPU aggregation runtime: 0.677375226020813
#
# --> End of Experiment.

# %%
RULE = 'fl_defender'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
